# %%
import ROOT
from quickstats.components import AnalysisObject, ExtendedModel, ExtendedMinimizer
# Out:
# Welcome to JupyROOT 6.22/08
#
# RooFit v3.60 -- Developed by Wouter Verkerke and David Kirkby
#                 Copyright (C) 2000-2013 NIKHEF, University of California & Stanford University
#                 All rights reserved, please read http://roofit.sourceforge.net/license.txt

# %%
filename1 = "/afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/debug/temp_combined.root"
filename2 = "/afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/python_modules/temp_combined.root"
model1 = ExtendedModel(filename1)
model2 = ExtendedModel(filename2)
# Out:
# INFO: Opening file "/afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/debug/temp_combined.root"
# INFO: Loaded workspace "combWS"
# INFO: Loaded model config "ModelConfig"
# INFO: Activated binned likelihood attribute for Region_BMin0_incJet1_Y2015_DZllbbCR_T2_L2_distmLL_J2_model_bbtautau
# INFO: Activated binned likelihood attribute for Region_BMin0_incJet1_distNN_J2_DSM_T2_SpcTauLH_Y2015_LTT0_L1_model_bbtautau
# INFO: Activated binned likelihood attribute for Region_BMin0_incJet1_distNN_J2_DSM_T2_SpcTauLH_Y2015_LTT1_L1_model_bbtautau
# INFO: Activated binned likelihood attribute for Region_BMin0_incJet1_distSMBDT_J2_Y2015_DLLOS_T2_SpcTauHH_L0_model_bbtautau
# INFO: Loaded model pdf "combPdf" from model config
# INFO: Loaded dataset "combData" from workspace
# INFO: Loaded nuisance parameters from model config
# INFO: Loaded global observables from model config
# INFO: Loaded parameters of interest from model config
# INFO: Loaded observables from model config
# ...

# %%
# model.workspace.saveSnapshot("nominalAllVars", model.workspace.allVars())
# model.generate_asimov(poi_name="mu_XS_HH", poi_val=0, poi_profile=0, asimov_name="Asimov_profile_B_only")
model2.generate_asimov(poi_name="xsec_br", poi_val=1, poi_profile=1, do_fit=False, asimov_name="Asimov_profile_S_plus_B")
model1.generate_asimov(poi_name="xsec_br", poi_val=1, poi_profile=1, do_fit=False, asimov_name="Asimov_profile_S_plus_B")

# model.generate_asimov(poi_name="mu_XS_HH", poi_val=0, asimov_name="Asimov_no_profile_B_only")
# model.generate_asimov(poi_name="mu_XS_HH", poi_val=1, asimov_name="Asimov_no_profile_S_plus_B")
# Out:
# INFO: Generated Asimov Dataset `Asimov_profile_S_plus_B`
# INFO: Generated Asimov Dataset `Asimov_profile_S_plus_B`
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(combWS) replacing previous snapshot with name nominalVars
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(combWS) replacing previous snapshot with name conditionalGlobs_1
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(combWS) replacing previous snapshot with name conditionalNuis_1
# [#1] INFO:ObjectHandling -- RooWorkspace::import(combWS) importing dataset Asimov_profile_S_plus_B
# [#0] ERROR:ObjectHandling -- RooWorkspace::import(combWS) ERROR dataset with name Asimov_profile_S_plus_B already exists in workspace, import aborted
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(combWS) replacing previous snapshot with name nominalVars
# [#1] INFO:ObjectHandling -- RooWorkspace::saveSnaphot(combWS) replacing previous snapshot with name conditionalGlobs_1
# ...

# %%
model1.print_summary()
# Out:
# Workspace:
# 	combWS
# Datasets (3):
# 	combData, asimovData_1_paz, asimovData_1_NP_Nominal
# Categories (8):
# 	combCat_Region_BMin0_incJet1_distNN_J2_DSM_T2_SpcTauLH_Y2015_LTT0_L1_bbtautau
# 	combCat_Region_BMin0_incJet1_distSMBDT_J2_Y2015_DLLOS_T2_SpcTauHH_L0_bbtautau
# 	combCat_Region_BMin0_incJet1_Y2015_DZllbbCR_T2_L2_distmLL_J2_bbtautau
# 	combCat_Region_BMin0_incJet1_distNN_J2_DSM_T2_SpcTauLH_Y2015_LTT1_L1_bbtautau
# 	combCat_SM_1_bbyy
# 	combCat_SM_2_bbyy
# 	combCat_BSM_1_bbyy
# 	combCat_BSM_2_bbyy
# POIs (1):
# 	xsec_br = 1.0 [-1.0, 20.0] C
# Constrained NPs (196):
# 	ATLAS_EG_RESOLUTION_ALL = 0.0 [-5.0, 5.0] F
# 	ATLAS_EG_SCALE_ALL_bbyy = 0.0 [-5.0, 5.0] F
# 	THEO_BR_Hbb = 0.0 [-5.0, 5.0] F
# 	THEO_XS_fixmu_SCALE_VBFHH = 0.0 [-5.0, 5.0] F
# 	THEO_XS_fixmu_PDFalphas_VBFHH = 0.0 [-5.0, 5.0] F
# 	THEO_ACC_PS_VBFHH_bbyy = 0.0 [-5.0, 5.0] F
# 	ATLAS_JET_JER_EffectiveNP_11 = 0.0 [-5.0, 5.0] F
# 	ATLAS_PU_PRW_DATASF = 0.0 [-5.0, 5.0] F
# ...

# %%
model2.print_summary()
# Out:
# Workspace:
# 	combWS
# Datasets (3):
# 	combData, asimovData_1_paz, asimovData_1_NP_Nominal
# Categories (8):
# 	combCat_Region_BMin0_incJet1_distNN_J2_DSM_T2_SpcTauLH_Y2015_LTT0_L1_bbtautau
# 	combCat_Region_BMin0_incJet1_distSMBDT_J2_Y2015_DLLOS_T2_SpcTauHH_L0_bbtautau
# 	combCat_Region_BMin0_incJet1_Y2015_DZllbbCR_T2_L2_distmLL_J2_bbtautau
# 	combCat_Region_BMin0_incJet1_distNN_J2_DSM_T2_SpcTauLH_Y2015_LTT1_L1_bbtautau
# 	combCat_SM_1_bbyy
# 	combCat_SM_2_bbyy
# 	combCat_BSM_1_bbyy
# 	combCat_BSM_2_bbyy
# POIs (1):
# 	xsec_br = 1.0 [-1.0, 20.0] C
# Constrained NPs (196):
# 	ATLAS_EG_RESOLUTION_ALL = 0.0 [-5.0, 5.0] F
# 	ATLAS_EG_SCALE_ALL_bbyy = 0.0 [-5.0, 5.0] F
# 	THEO_BR_Hbb = 0.0 [-5.0, 5.0] F
# 	THEO_XS_fixmu_SCALE_VBFHH = 0.0 [-5.0, 5.0] F
# 	THEO_XS_fixmu_PDFalphas_VBFHH = 0.0 [-5.0, 5.0] F
# 	THEO_ACC_PS_VBFHH_bbyy = 0.0 [-5.0, 5.0] F
# 	ATLAS_JET_JER_EffectiveNP_11 = 0.0 [-5.0, 5.0] F
# 	ATLAS_PU_PRW_DATASF = 0.0 [-5.0, 5.0] F
# ...

# %%
plt = model1.plot_distributions(category='combCat_SM_1_bbyy',
                               current_distributions=True,
                               datasets=[
                                         "asimovData_1_paz",
                                   "asimovData_1_NP_Nominal",

#                                          "asimovData_1_NP_Nominal"
                                        ])
                                 #snapshots=["nominalAllVars"])
plt.show()

# %%
plt = model2.plot_distributions(category='combCat_SM_1_bbyy',
                               current_distributions=True,
                               datasets=[
#                                    "Asimov_profile_S_plus_B",
                                         "asimovData_1_paz",
                                         "asimovData_1_NP_Nominal"
                                        ])
                                 #snapshots=["nominalAllVars"])
plt.show()

# %%
plt = model.plot_distributions(category='BSM_1',
                               current_distributions=True,
                               datasets=["Asimov_profile_B_only", 
                                         "Asimov_profile_S_plus_B",
                                         "Asimov_no_profile_B_only",
                                         "Asimov_no_profile_S_plus_B"])
                                 #snapshots=["nominalAllVars"])
plt.show()

# %%
plt = model.plot_distributions(category='BSM_2',
                               current_distributions=True,
                               datasets=["Asimov_profile_B_only", 
                                         "Asimov_profile_S_plus_B",
                                         "Asimov_no_profile_B_only",
                                         "Asimov_no_profile_S_plus_B"])
                                 #snapshots=["nominalAllVars"])
plt.show()
