# %% [markdown]
# Login to lxplus:
#
# - ssh -L 8081:localhost:8081 zhangr@lxplus711.cern.ch
#
# Then on lxplus:
#
# - export PATH=/afs/cern.ch/work/c/chlcheng/public/local/conda/miniconda/envs/ml-base/bin:$PATH
#
# - jupyter notebook --no-browser --port 8081

# %%
import ROOT
from quickstats.components import AnalysisObject, ExtendedModel, ExtendedMinimizer
# %matplotlib inline
# Out:
# Welcome to JupyROOT 6.24/06
#
# RooFit v3.60 -- Developed by Wouter Verkerke and David Kirkby
#                 Copyright (C) 2000-2013 NIKHEF, University of California & Stanford University
#                 All rights reserved, please read http://roofit.sourceforge.net/license.txt

# %%
filepath1 = "/afs/cern.ch/user/z/zhangr/work/HH4b/hh4b-vbf-limits/RooWorkspaceIza_lowth/"
filepath2 = "/afs/cern.ch/user/z/zhangr/work/HH4b/hh4b-vbf-limits/RooWorkspaceTREx_nobb_unblind2_larglumi_SeparateGammas_bkgnodata_POI10/RooStats/HH4b_K1p0_C18_Vm_hh_Q45_nocor_NC_combined_HH4b_K1p0_C18_Vm_hh_Q45_nocor_NC_model_forLimits.root"
file_1 = '125.root'
file_2 = ''
model1 = ExtendedModel(filepath1+file_1, data_name="obsData")
model2 = ExtendedModel(filepath2+file_2, data_name="obsData")
# Out:
# INFO: Opening file "/afs/cern.ch/user/z/zhangr/work/HH4b/hh4b-vbf-limits/RooWorkspaceIza_lowth/125.root"
# INFO: Loaded workspace "combined"
# INFO: Loaded model config "ModelConfig"
# INFO: Activated binned likelihood attribute for Region_distmHH_L0_Y2016_T4_J4_BMin0_DSRhighdEtainXhh_model
# INFO: Activated binned likelihood attribute for Region_distmHH_L0_Y2016_T4_J4_BMin0_DSRhighdEtaoutXhh_model
# INFO: Activated binned likelihood attribute for Region_distmHH_L0_Y2016_T4_J4_BMin0_DSRlowdEtainXhh_model
# INFO: Activated binned likelihood attribute for Region_distmHH_L0_Y2016_T4_J4_BMin0_DSRlowdEtaoutXhh_model
# INFO: Activated binned likelihood attribute for Region_distmHH_L0_Y2016_T4_J4_BMin0_DSRmiddEtainXhh_model
# INFO: Activated binned likelihood attribute for Region_distmHH_L0_Y2016_T4_J4_BMin0_DSRmiddEtaoutXhh_model
# INFO: Activated binned likelihood attribute for Region_distmHH_L0_Y2017_T4_J4_BMin0_DSRhighdEtainXhh_model
# INFO: Activated binned likelihood attribute for Region_distmHH_L0_Y2017_T4_J4_BMin0_DSRhighdEtaoutXhh_model
# INFO: Activated binned likelihood attribute for Region_distmHH_L0_Y2017_T4_J4_BMin0_DSRlowdEtainXhh_model
# INFO: Activated binned likelihood attribute for Region_distmHH_L0_Y2017_T4_J4_BMin0_DSRlowdEtaoutXhh_model
# INFO: Activated binned likelihood attribute for Region_distmHH_L0_Y2017_T4_J4_BMin0_DSRmiddEtainXhh_model
# INFO: Activated binned likelihood attribute for Region_distmHH_L0_Y2017_T4_J4_BMin0_DSRmiddEtaoutXhh_model
# INFO: Activated binned likelihood attribute for Region_distmHH_L0_Y2018_T4_J4_BMin0_DSRhighdEtainXhh_model
# INFO: Activated binned likelihood attribute for Region_distmHH_L0_Y2018_T4_J4_BMin0_DSRhighdEtaoutXhh_model
# INFO: Activated binned likelihood attribute for Region_distmHH_L0_Y2018_T4_J4_BMin0_DSRlowdEtainXhh_model
# INFO: Activated binned likelihood attribute for Region_distmHH_L0_Y2018_T4_J4_BMin0_DSRlowdEtaoutXhh_model
# INFO: Activated binned likelihood attribute for Region_distmHH_L0_Y2018_T4_J4_BMin0_DSRmiddEtainXhh_model
# INFO: Activated binned likelihood attribute for Region_distmHH_L0_Y2018_T4_J4_BMin0_DSRmiddEtaoutXhh_model
# INFO: Loaded model pdf "simPdf" from model config
# INFO: Loaded dataset "obsData" from workspace
# INFO: Loaded nuisance parameters from model config
# INFO: Loaded global observables from model config
# INFO: Loaded parameters of interest from model config
# INFO: Loaded observables from model config
# INFO: Opening file "/afs/cern.ch/user/z/zhangr/work/HH4b/hh4b-vbf-limits/RooWorkspaceTREx_nobb_unblind2_larglumi_SeparateGammas_bkgnodata_POI10/RooStats/HH4b_K1p0_C18_Vm_hh_Q45_nocor_NC_combined_HH4b_K1p0_C18_Vm_hh_Q45_nocor_NC_model_forLimits.root"
# INFO: Loaded workspace "combined"
# INFO: Loaded model config "ModelConfig"
# INFO: Activated binned likelihood attribute for SMNR_R16_4b_dEta_1_Xhh_1__m_hh_model
# INFO: Activated binned likelihood attribute for SMNR_R16_4b_dEta_1_Xhh_2__m_hh_model
# INFO: Activated binned likelihood attribute for SMNR_R16_4b_dEta_2_Xhh_1__m_hh_model
# INFO: Activated binned likelihood attribute for SMNR_R16_4b_dEta_2_Xhh_2__m_hh_model
# INFO: Activated binned likelihood attribute for SMNR_R16_4b_dEta_3_Xhh_1__m_hh_model
# INFO: Activated binned likelihood attribute for SMNR_R16_4b_dEta_3_Xhh_2__m_hh_model
# INFO: Activated binned likelihood attribute for SMNR_R17_4b_dEta_1_Xhh_1__m_hh_model
# INFO: Activated binned likelihood attribute for SMNR_R17_4b_dEta_1_Xhh_2__m_hh_model
# INFO: Activated binned likelihood attribute for SMNR_R17_4b_dEta_2_Xhh_1__m_hh_model
# INFO: Activated binned likelihood attribute for SMNR_R17_4b_dEta_2_Xhh_2__m_hh_model
# INFO: Activated binned likelihood attribute for SMNR_R17_4b_dEta_3_Xhh_1__m_hh_model
# INFO: Activated binned likelihood attribute for SMNR_R17_4b_dEta_3_Xhh_2__m_hh_model
# INFO: Activated binned likelihood attribute for SMNR_R18_4b_dEta_1_Xhh_1__m_hh_model
# INFO: Activated binned likelihood attribute for SMNR_R18_4b_dEta_1_Xhh_2__m_hh_model
# INFO: Activated binned likelihood attribute for SMNR_R18_4b_dEta_2_Xhh_1__m_hh_model
# INFO: Activated binned likelihood attribute for SMNR_R18_4b_dEta_2_Xhh_2__m_hh_model
# INFO: Activated binned likelihood attribute for SMNR_R18_4b_dEta_3_Xhh_1__m_hh_model
# INFO: Activated binned likelihood attribute for SMNR_R18_4b_dEta_3_Xhh_2__m_hh_model
# INFO: Loaded model pdf "simPdf" from model config
# INFO: Loaded dataset "obsData" from workspace
# INFO: Loaded nuisance parameters from model config
# INFO: Loaded global observables from model config
# INFO: Loaded parameters of interest from model config
# INFO: Loaded observables from model config

# %%
# model1.print_summary()
# model2.print_summary()
model1.get_categories(), model2.get_categories()
# Out:
# (['Region_distmHH_L0_Y2016_T4_J4_BMin0_DSRhighdEtainXhh',
#   'Region_distmHH_L0_Y2017_T4_J4_BMin0_DSRhighdEtainXhh',
#   'Region_distmHH_L0_Y2018_T4_J4_BMin0_DSRhighdEtainXhh',
#   'Region_distmHH_L0_Y2016_T4_J4_BMin0_DSRmiddEtainXhh',
#   'Region_distmHH_L0_Y2017_T4_J4_BMin0_DSRmiddEtainXhh',
#   'Region_distmHH_L0_Y2018_T4_J4_BMin0_DSRmiddEtainXhh',
#   'Region_distmHH_L0_Y2016_T4_J4_BMin0_DSRlowdEtainXhh',
#   'Region_distmHH_L0_Y2017_T4_J4_BMin0_DSRlowdEtainXhh',
#   'Region_distmHH_L0_Y2018_T4_J4_BMin0_DSRlowdEtainXhh',
#   'Region_distmHH_L0_Y2016_T4_J4_BMin0_DSRhighdEtaoutXhh',
#   'Region_distmHH_L0_Y2017_T4_J4_BMin0_DSRhighdEtaoutXhh',
#   'Region_distmHH_L0_Y2018_T4_J4_BMin0_DSRhighdEtaoutXhh',
#   'Region_distmHH_L0_Y2016_T4_J4_BMin0_DSRmiddEtaoutXhh',
#   'Region_distmHH_L0_Y2017_T4_J4_BMin0_DSRmiddEtaoutXhh',
#   'Region_distmHH_L0_Y2018_T4_J4_BMin0_DSRmiddEtaoutXhh',
#   'Region_distmHH_L0_Y2016_T4_J4_BMin0_DSRlowdEtaoutXhh',
#   'Region_distmHH_L0_Y2017_T4_J4_BMin0_DSRlowdEtaoutXhh',
#   'Region_distmHH_L0_Y2018_T4_J4_BMin0_DSRlowdEtaoutXhh'],
#  ['SMNR_R16_4b_dEta_1_Xhh_1__m_hh',
#   'SMNR_R16_4b_dEta_1_Xhh_2__m_hh',
#   'SMNR_R16_4b_dEta_2_Xhh_1__m_hh',
#   'SMNR_R16_4b_dEta_2_Xhh_2__m_hh',
#   'SMNR_R16_4b_dEta_3_Xhh_1__m_hh',
#   'SMNR_R16_4b_dEta_3_Xhh_2__m_hh',
#   'SMNR_R17_4b_dEta_1_Xhh_1__m_hh',
#   'SMNR_R17_4b_dEta_1_Xhh_2__m_hh',
#   'SMNR_R17_4b_dEta_2_Xhh_1__m_hh',
#   'SMNR_R17_4b_dEta_2_Xhh_2__m_hh',
#   'SMNR_R17_4b_dEta_3_Xhh_1__m_hh',
#   'SMNR_R17_4b_dEta_3_Xhh_2__m_hh',
#   'SMNR_R18_4b_dEta_1_Xhh_1__m_hh',
#   'SMNR_R18_4b_dEta_1_Xhh_2__m_hh',
#   'SMNR_R18_4b_dEta_2_Xhh_1__m_hh',
#   'SMNR_R18_4b_dEta_2_Xhh_2__m_hh',
#   'SMNR_R18_4b_dEta_3_Xhh_1__m_hh',
#   'SMNR_R18_4b_dEta_3_Xhh_2__m_hh'])

# %%
# !quickstats generate_standard_asimov -i {filename} -o test.root --poi xsec_br --poi_scale 0.032776 --asimov_types 2,5

# %%
# model = ExtendedModel("test.root")
# model.print_summary()

# %%
# model.pair_constraints(to_str=True)

# %%
plt1 = model1.plot_distributions(categories=['Region_distmHH_L0_Y2016_T4_J4_BMin0_DSRlowdEtainXhh', 'Region_distmHH_L0_Y2016_T4_J4_BMin0_DSRlowdEtaoutXhh'],
                               current_distributions=True,
                               datasets=["obsData",
                                        ])
plt1

# %%
plt2 = model2.plot_distributions(categories=['SMNR_R16_4b_dEta_1_Xhh_1__m_hh', 'SMNR_R16_4b_dEta_1_Xhh_2__m_hh'],
                               current_distributions=True,
                               datasets=["obsData",
                                        ])
plt2

# %%
from quickstats.components import ExtendedModel
model1 = ExtendedModel("/afs/cern.ch/user/z/zhangr/work/HH4b/hh4b-vbf-limits/RooWorkspaceIza_lowth/125.root", data_name="obsData")
model2 = ExtendedModel("/afs/cern.ch/user/z/zhangr/work/HH4b/hh4b-vbf-limits/RooWorkspaceTREx_nobb_unblind2_larglumi_SeparateGammas_bkgnodata/RooStats/HH4b_K1p0_C18_Vm_hh_Q45_nocor_NC_combined_HH4b_K1p0_C18_Vm_hh_Q45_nocor_NC_model_forLimits.root", data_name="obsData")
sumpdf1 = model1.workspace.pdf("Region_distmHH_L0_Y2016_T4_J4_BMin0_DSRlowdEtainXhh_model")
sumpdf2 = model2.workspace.pdf("SMNR_R16_4b_dEta_1_Xhh_1__m_hh_model")

sumpdf1.printComponentTree()

sumpdf2.printComponentTree()

# %%
model.workspace.saveSnapshot("nominalAllVars", model.workspace.allVars())
model.generate_asimov(poi_name="xsec_br", poi_val=0.032776, poi_profile=0.032776, asimov_name="Asimov_profile_S_plus_B")
model.generate_asimov(poi_name="xsec_br", poi_val=0.032776, poi_profile=None, asimov_name="Asimov_1")
# Out:
# INFO: Created ExtendedMinimizer("Minimizer") instance

# %%
model.fix_parameters("ATLAS_*=0,THEO_*=0,alpha_*=0,SPURIOUS_*=0")
# model.generate_asimov(poi_name="xsec_br", poi_val=0, poi_profile=0, asimov_name="Asimov_profile_B_only")
model.generate_asimov(poi_name="xsec_br", poi_val=0.032776, poi_profile=0.032776, asimov_name="Asimov_partial_profile_S_plus_B")
# model.generate_asimov(poi_name="xsec_br", poi_val=0, asimov_name="Asimov_no_profile_B_only")
# model.generate_asimov(poi_name="xsec_br", poi_val=1, asimov_name="Asimov_no_profile_S_plus_B")
# Out:
# INFO: Fixed parameter "ATLAS_LHCmass" at value 0.0
# INFO: Fixed parameter "ATLAS_EG_SCALE_ALL" at value 0.0
# INFO: Fixed parameter "ATLAS_EG_RESOLUTION_ALL" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_JER_EffectiveNP_11" at value 0.0
# INFO: Fixed parameter "ATLAS_PRW_DATASF" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_JER_EffectiveNP_10" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_Pileup_PtTerm" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_EffectiveNP_Statistical2" at value 0.0
# INFO: Fixed parameter "ATLAS_PH_EFF_TRIGGER_Uncertainty" at value 0.0
# INFO: Fixed parameter "ATLAS_PH_EFF_ISO_Uncertainty" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_EtaIntercalibration_NonClosure_2018data" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_Pileup_RhoTopology" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_JER_EffectiveNP_8" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_Flavor_Composition" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_Pileup_OffsetMu" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_fJvtEfficiency" at value 0.0
# INFO: Fixed parameter "ATLAS_FT_EFF_Eigen_B_1" at value 0.0
# INFO: Fixed parameter "ATLAS_FT_EFF_Eigen_B_0" at value 0.0
# INFO: Fixed parameter "ATLAS_PH_EFF_ID_Uncertainty" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_JER_EffectiveNP_5" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_JER_EffectiveNP_4" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_JER_EffectiveNP_7" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_JER_EffectiveNP_12restTerm" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_JER_EffectiveNP_1" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_JER_EffectiveNP_3" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_JER_EffectiveNP_2" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_EtaIntercalibration_Modelling" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_JER_EffectiveNP_9" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_BJES_Response" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_EffectiveNP_Modelling1" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_EffectiveNP_Modelling3" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_Pileup_OffsetNPV" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_EtaIntercalibration_TotalStat" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_EffectiveNP_Mixed2" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_EffectiveNP_Mixed1" at value 0.0
# INFO: Fixed parameter "ATLAS_FT_EFF_Eigen_Light_0" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_JER_EffectiveNP_6" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_Flavor_Response" at value 0.0
# INFO: Fixed parameter "ATLAS_lumi_run2" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_EffectiveNP_Detector1" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_EffectiveNP_Mixed3" at value 0.0
# INFO: Fixed parameter "ATLAS_FT_EFF_Eigen_Light_1" at value 0.0
# INFO: Fixed parameter "ATLAS_FT_EFF_Eigen_C_2" at value 0.0
# INFO: Fixed parameter "ATLAS_FT_EFF_Eigen_C_3" at value 0.0
# INFO: Fixed parameter "ATLAS_FT_EFF_Eigen_C_0" at value 0.0
# INFO: Fixed parameter "ATLAS_HF_ggH" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_EffectiveNP_Statistical1" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_EffectiveNP_Statistical3" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_EffectiveNP_Statistical5" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_EffectiveNP_Statistical4" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_EffectiveNP_Statistical6" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_EffectiveNP_Detector2" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_EffectiveNP_Modelling2" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_EffectiveNP_Modelling4" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_EtaIntercalibration_NonClosure_negEta" at value 0.0
# INFO: Fixed parameter "ATLAS_HF_VBF" at value 0.0
# INFO: Fixed parameter "ATLAS_HF_WH" at value 0.0
# INFO: Fixed parameter "ATLAS_FT_EFF_Eigen_B_2" at value 0.0
# INFO: Fixed parameter "ATLAS_FT_EFF_Eigen_Light_4" at value 0.0
# INFO: Fixed parameter "ATLAS_FT_EFF_Eigen_C_1" at value 0.0
# INFO: Fixed parameter "ATLAS_JET_EtaIntercalibration_NonClosure_posEta" at value 0.0
# INFO: Fixed parameter "ATLAS_FT_EFF_Eigen_Light_3" at value 0.0
# INFO: Fixed parameter "THEO_BR_Hbb" at value 0.0
# INFO: Fixed parameter "THEO_XS_COMBINED_HH_ggF" at value 0.0
# INFO: Fixed parameter "THEO_XS_PDFalphas_HH_ggF" at value 0.0
# INFO: Fixed parameter "THEO_ACC_PDFalphas_HH_ggF" at value 0.0
# INFO: Fixed parameter "THEO_ACC_SCALE_HH_ggF" at value 0.0
# INFO: Fixed parameter "THEO_ACC_PS_HH_ggF" at value 0.0
# INFO: Fixed parameter "THEO_BR_Hyy" at value 0.0
# INFO: Fixed parameter "THEO_XS_SCALE_HH_VBF" at value 0.0
# INFO: Fixed parameter "THEO_XS_PDFalphas_HH_VBF" at value 0.0
# INFO: Fixed parameter "THEO_ACC_PS_HH_VBF" at value 0.0
# INFO: Fixed parameter "THEO_YIELD_PDFalphas_ttH" at value 0.0
# INFO: Fixed parameter "THEO_YIELD_SCALE_ttH" at value 0.0
# INFO: Fixed parameter "THEO_ACC_PS_ttH" at value 0.0
# INFO: Fixed parameter "THEO_YIELD_PDFalphas_ZH" at value 0.0
# INFO: Fixed parameter "THEO_YIELD_SCALE_ZH" at value 0.0
# INFO: Fixed parameter "THEO_ACC_PS_ZH" at value 0.0
# WARNING: Parameter "alpha_*" does not exist. No modification will be made.
# INFO: Fixed parameter "SPURIOUS_SM_1" at value 0.0
# INFO: Fixed parameter "SPURIOUS_SM_2" at value 0.0
# INFO: Fixed parameter "SPURIOUS_BSM_1" at value 0.0
# INFO: Fixed parameter "SPURIOUS_BSM_2" at value 0.0
# INFO: Created ExtendedMinimizer("Minimizer") instance

# %%
model.print_summary()
# Out:
# workspace: combWS
#
# POIs: xsec_br
#
# datasets: combData, combDatabinned, asimovData_0, asimovData_1, Asimov_profile_S_plus_B, Asimov_partial_profile_S_plus_B, Asimov_1
#
# observables: atlas_invMass_SM_1, atlas_invMass_SM_2, atlas_invMass_BSM_1, atlas_invMass_BSM_2, channellist

# %%
model.get_categories()
# Out:
# ['SM_1', 'SM_2', 'BSM_1', 'BSM_2']

# %%
plt = model.plot_distributions(category='SM_1',
                               current_distributions=False,
                               datasets=[#"combData",
                                         "asimovData_0",
#                                          "dataset_temp",
                                        "asimovData_1",
                               "Asimov_profile_S_plus_B",
                               "Asimov_partial_profile_S_plus_B",
                               "Asimov_1"])
                                 #snapshots=["nominalAllVars"])
plt.show()

# %%
filename2 = "/eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/batches/v140invfb_20210903_CI/output_mu_unblind/rescaled/nonres/bbtautau/asimov_temp-2.root"
model2 = ExtendedModel(filename2)
model2.print_summary()
# Out:
# INFO: Opening file "/eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/batches/v140invfb_20210903_CI/output_mu_unblind/rescaled/nonres/bbtautau/asimov_temp-2.root"
# INFO: Loaded workspace "combWS"
# INFO: Loaded model config "ModelConfig"
# INFO: Activating binned likelihood evaluation
# INFO: Activated binned likelihood attribute for Region_BMin0_incJet1_Y2015_DZllbbCR_T2_L2_distmLL_J2_model
# INFO: Activated binned likelihood attribute for Region_BMin0_incJet1_distNN_J2_DSM_T2_SpcTauLH_Y2015_LTT0_L1_model
# INFO: Activated binned likelihood attribute for Region_BMin0_incJet1_distNN_J2_DSM_T2_SpcTauLH_Y2015_LTT1_L1_model
# INFO: Activated binned likelihood attribute for Region_BMin0_incJet1_distSMBDT_J2_Y2015_DLLOS_T2_SpcTauHH_L0_model
# INFO: Loaded model pdf "simPdf" from model config
# INFO: Loaded dataset "combData" from workspace
# INFO: Loaded nuisance parameters from model config
# INFO: Loaded global observables from model config
# INFO: Loaded parameters of interest from model config
# INFO: Loaded observables from model config
# workspace: combWS
#
# POIs: xsec_br
#
# datasets: asimovData, combData, asimovDataAtLimit, dataset_temp
#
# observables: obs_x_Region_BMin0_incJet1_distNN_J2_DSM_T2_SpcTauLH_Y2015_LTT0_L1, obs_x_Region_BMin0_incJet1_distSMBDT_J2_Y2015_DLLOS_T2_SpcTauHH_L0, obs_x_Region_BMin0_incJet1_Y2015_DZllbbCR_T2_L2_distmLL_J2, obs_x_Region_BMin0_incJet1_distNN_J2_DSM_T2_SpcTauLH_Y2015_LTT1_L1, weightVar, channelCat

# %%
model2.get_categories()
# Out:
# ['Region_BMin0_incJet1_distNN_J2_DSM_T2_SpcTauLH_Y2015_LTT0_L1',
#  'Region_BMin0_incJet1_distSMBDT_J2_Y2015_DLLOS_T2_SpcTauHH_L0',
#  'Region_BMin0_incJet1_Y2015_DZllbbCR_T2_L2_distmLL_J2',
#  'Region_BMin0_incJet1_distNN_J2_DSM_T2_SpcTauLH_Y2015_LTT1_L1']

# %%
plt2 = model2.plot_distributions(category='Region_BMin0_incJet1_distSMBDT_J2_Y2015_DLLOS_T2_SpcTauHH_L0',
                               current_distributions=True,
                               datasets=["combData", 
                                         "asimovData",
                                         "dataset_temp"])
                                 #snapshots=["nominalAllVars"])
plt2.show()
# Out:
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(Region_BMin0_incJet1_distNN_J2_DSM_T2_SpcTauLH_Y2015_LTT0_L1_model_Int[obs_x_Region_BMin0_incJet1_distNN_J2_DSM_T2_SpcTauLH_Y2015_LTT0_L1]) using numeric integrator RooBinIntegrator to calculate Int(obs_x_Region_BMin0_incJet1_distNN_J2_DSM_T2_SpcTauLH_Y2015_LTT0_L1)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(Region_BMin0_incJet1_distSMBDT_J2_Y2015_DLLOS_T2_SpcTauHH_L0_model_Int[obs_x_Region_BMin0_incJet1_distSMBDT_J2_Y2015_DLLOS_T2_SpcTauHH_L0]) using numeric integrator RooBinIntegrator to calculate Int(obs_x_Region_BMin0_incJet1_distSMBDT_J2_Y2015_DLLOS_T2_SpcTauHH_L0)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(Region_BMin0_incJet1_Y2015_DZllbbCR_T2_L2_distmLL_J2_model_Int[obs_x_Region_BMin0_incJet1_Y2015_DZllbbCR_T2_L2_distmLL_J2]) using numeric integrator RooBinIntegrator to calculate Int(obs_x_Region_BMin0_incJet1_Y2015_DZllbbCR_T2_L2_distmLL_J2)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(Region_BMin0_incJet1_distNN_J2_DSM_T2_SpcTauLH_Y2015_LTT1_L1_model_Int[obs_x_Region_BMin0_incJet1_distNN_J2_DSM_T2_SpcTauLH_Y2015_LTT1_L1]) using numeric integrator RooBinIntegrator to calculate Int(obs_x_Region_BMin0_incJet1_distNN_J2_DSM_T2_SpcTauLH_Y2015_LTT1_L1)

# %%
plt = model.plot_distributions(category='SM_2',
                               current_distributions=True,
                               datasets=["combData",
                                         "asimovData_1",
                                         "dataset_temp",])
                                 #snapshots=["nominalAllVars"])
plt.show()

# %%
plt = model.plot_distributions(category='BSM_1',
                               current_distributions=True,
                               datasets=[#"combData",
                                         "asimovData_1",
                                         "dataset_temp",])
                                 #snapshots=["nominalAllVars"])
plt.show()

# %%
plt = model.plot_distributions(category='BSM_2',
                               current_distributions=True,
                               datasets=["Asimov_profile_B_only", 
                                         "Asimov_profile_S_plus_B",
                                         "Asimov_no_profile_B_only",
                                         "Asimov_no_profile_S_plus_B"])
                                 #snapshots=["nominalAllVars"])
plt.show()
