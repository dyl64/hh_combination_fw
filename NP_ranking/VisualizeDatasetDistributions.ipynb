# %% [markdown]
# Login to lxplus:
#
# - ssh -L 8081:localhost:8081 zhangr@lxplus711.cern.ch
#
# Then on lxplus:
#
# - export PATH=/afs/cern.ch/work/c/chlcheng/public/local/conda/miniconda/envs/ml-base/bin:$PATH
#
# - jupyter notebook --no-browser --port 8081

# %%
import ROOT
from quickstats.components import AnalysisObject, ExtendedModel, ExtendedMinimizer
# Out:
# Welcome to JupyROOT 6.22/08
#
# RooFit v3.60 -- Developed by Wouter Verkerke and David Kirkby
#                 Copyright (C) 2000-2013 NIKHEF, University of California & Stanford University
#                 All rights reserved, please read http://roofit.sourceforge.net/license.txt
# /afs/cern.ch/work/c/chlcheng/public/local/conda/miniconda/envs/ml-base/lib/python3.7/site-packages/uproot/reading.py:186: FutureWarning: XRootD 5.1.1 is not fully supported; either upgrade to 5.2.0+ or set
#
#     open.defaults["xrootd_handler"] = uproot.MultithreadedXRootDSource
#
#   warnings.warn(message, FutureWarning)

# %%
filename = "bbyy_asimov_-1.root"
model = ExtendedModel(filename)
# Out:
# INFO: Loaded extension module "RooTwoSidedCBShape"
# INFO: Opening file "bbyy_asimov_-1.root"
# INFO: Loaded workspace "combWS"
# INFO: Loaded model config "ModelConfig"
# INFO: Activating binned likelihood evaluation
# INFO: Loaded model pdf "CombinedPdf" from model config
# INFO: Loaded dataset "combData" from workspace
# INFO: Loaded nuisance parameters from model config
# INFO: Loaded global observables from model config
# INFO: Loaded parameters of interest from model config
# INFO: Loaded observables from model config

# %%
# model.workspace.saveSnapshot("nominalAllVars", model.workspace.allVars())
# model.generate_asimov(poi_name="mu_XS_HH", poi_val=0, poi_profile=0, asimov_name="Asimov_profile_B_only")
# model.generate_asimov(poi_name="mu_XS_HH", poi_val=1, poi_profile=1, asimov_name="Asimov_profile_S_plus_B")
# model.generate_asimov(poi_name="mu_XS_HH", poi_val=0, asimov_name="Asimov_no_profile_B_only")
# model.generate_asimov(poi_name="mu_XS_HH", poi_val=1, asimov_name="Asimov_no_profile_S_plus_B")
# Out:
# INFO: Created ExtendedMinimizer("Minimizer") instance
# INFO: Created ExtendedMinimizer("Minimizer") instance

# %%
model.print_summary()
# Out:
# workspace: combWS
#
# POIs: xsec_br
#
# datasets: combData, combDatabinned, asimovData_0, asimovData_1, dataset_temp
#
# observables: atlas_invMass_SM_1, atlas_invMass_SM_2, atlas_invMass_BSM_1, atlas_invMass_BSM_2, channellist

# %%
model.get_categories()
# Out:
# ['SM_1', 'SM_2', 'BSM_1', 'BSM_2']

# %%
plt = model.plot_distributions(category='SM_1',
                               current_distributions=True,
                               datasets=["combData",
                                         "asimovData_1",
                                         "dataset_temp",])
                                 #snapshots=["nominalAllVars"])
plt.show()

# %%
filename2 = "bbyy_asimov_-1b.root"
model2 = ExtendedModel(filename2)
# Out:
# INFO: Opening file "bbyy_asimov_-1b.root"
# INFO: Loaded workspace "combWS"
# INFO: Loaded model config "ModelConfig"
# INFO: Activating binned likelihood evaluation
# INFO: Loaded model pdf "CombinedPdf" from model config
# INFO: Loaded dataset "combData" from workspace
# INFO: Loaded nuisance parameters from model config
# INFO: Loaded global observables from model config
# INFO: Loaded parameters of interest from model config
# INFO: Loaded observables from model config

# %%
plt2 = model2.plot_distributions(category='SM_1',
                               current_distributions=True,
                               datasets=["combData", 
                                         "asimovData_1",
                                         "dataset_temp",])
                                 #snapshots=["nominalAllVars"])
plt2.show()
# Out:
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(pdf__background_SM_1_Int[atlas_invMass_SM_1]) using numeric integrator RooIntegrator1D to calculate Int(atlas_invMass_SM_1)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(pdf__background_SM_2_Int[atlas_invMass_SM_2]) using numeric integrator RooIntegrator1D to calculate Int(atlas_invMass_SM_2)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(pdf__background_BSM_1_Int[atlas_invMass_BSM_1]) using numeric integrator RooIntegrator1D to calculate Int(atlas_invMass_BSM_1)
# [#1] INFO:NumericIntegration -- RooRealIntegral::init(pdf__background_BSM_2_Int[atlas_invMass_BSM_2]) using numeric integrator RooIntegrator1D to calculate Int(atlas_invMass_BSM_2)

# %%
plt = model.plot_distributions(category='SM_2',
                               current_distributions=True,
                               datasets=["combData",
                                         "asimovData_1",
                                         "dataset_temp",])
                                 #snapshots=["nominalAllVars"])
plt.show()

# %%
plt = model.plot_distributions(category='BSM_1',
                               current_distributions=True,
                               datasets=[#"combData",
                                         "asimovData_1",
                                         "dataset_temp",])
                                 #snapshots=["nominalAllVars"])
plt.show()

# %%
plt = model.plot_distributions(category='BSM_2',
                               current_distributions=True,
                               datasets=["Asimov_profile_B_only", 
                                         "Asimov_profile_S_plus_B",
                                         "Asimov_no_profile_B_only",
                                         "Asimov_no_profile_S_plus_B"])
                                 #snapshots=["nominalAllVars"])
plt.show()
