# %%
from typing import Optional, List, Dict
import os
import time
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
if "hh_combination_fw_path" not in os.environ:
    os.environ['hh_combination_fw_path'] = os.path.abspath("../../")

# %%
config = {
    'inputdir': '/eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI',
    # change your output directory here
    'outdir': os.path.join(os.environ['hh_combination_fw_path'], "outputs_newCDI"),
    'parameters':['cgghh', 'ctthh'],
    'channels': ['bbyy', 'bbtautau'],
    'resonant_type': 'nonres',
    'file_expr': {
        'cgghh': '<mass[F]>_cgghh_<cgghh[P]>',
        'ctthh': '<mass[F]>_ctthh_<ctthh[P]>'
    },
    'correlation_scheme': 'HEFT_nonres_v2.json',
    'task_option': 'HEFT_nonres_v1.yaml',
    'parallel': -1
}

# %%
def construct_commands(config:Dict):
    channels = ','.join(config['channels'])
    hhcomb_path = os.environ.get('hh_combination_fw_path', None)
    if hhcomb_path is None:
        raise RuntimeError("hh combination framework is not set up properly, please run setup.sh first")
    task_option_path = os.path.join(hhcomb_path, "configs", "task_options", config['task_option'])
    correlation_scheme_path = os.path.join(hhcomb_path, "configs", "correlation_schemes", config['correlation_scheme'])
    if not os.path.exists(task_option_path):
        raise FileNotFoundError(f"file \"{task_option_path}\" does not exist")
    if not os.path.exists(correlation_scheme_path):
        raise FileNotFoundError(f"file \"{correlation_scheme_path}\" does not exist")
    commands = {}
    for parameter in config['parameters']:
        commands[parameter] = []
        file_expr = config['file_expr'][parameter]
        input_path = os.path.join(config['inputdir'], parameter)
        output_path = os.path.join(config['outdir'], parameter)
        # process channels
        command_channel = f"HHComb process_channels -i {input_path} -c \"{channels}\" -r {config['resonant_type']} " +\
                          f"-o {output_path} --file_expr \"{file_expr}\" --config {task_option_path} " +\
                          f"--parallel {config['parallel']} --unblind --skip-limit"
        commands[parameter].append(command_channel)
        # combination
        command_comb = f"HHComb combine_ws -i {output_path} -s {correlation_scheme_path} -c \"{channels}\" " +\
                       f"-r {config['resonant_type']} --file_expr \"{file_expr}\" --config {task_option_path} " +\
                       f"--parallel {config['parallel']} --unblind"
        commands[parameter].append(command_comb)
    return commands

# %%
commands = construct_commands(config)

# %%
for parameter in commands:
    print(f"# commands for running {parameter} parameter scan")
    for sub_command in commands[parameter]:
        print("")
        print(sub_command)
    print("")
# Out:
# # commands for running cgghh parameter scan
#
# HHComb process_channels -i /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh -c "bbyy,bbtautau" -r nonres -o /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh --file_expr "<mass[F]>_cgghh_<cgghh[P]>" --config /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/configs/task_options/HEFT_nonres_v1.yaml --parallel -1 --unblind --skip-limit
#
# HHComb combine_ws -i /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh -s /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/configs/correlation_schemes/HEFT_nonres_v2.json -c "bbyy,bbtautau" -r nonres --file_expr "<mass[F]>_cgghh_<cgghh[P]>" --config /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/configs/task_options/HEFT_nonres_v1.yaml --parallel -1 --unblind
#
# # commands for running ctthh parameter scan
#
# HHComb process_channels -i /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/ctthh -c "bbyy,bbtautau" -r nonres -o /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh --file_expr "<mass[F]>_ctthh_<ctthh[P]>" --config /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/configs/task_options/HEFT_nonres_v1.yaml --parallel -1 --unblind --skip-limit
#
# HHComb combine_ws -i /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh -s /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/configs/correlation_schemes/HEFT_nonres_v2.json -c "bbyy,bbtautau" -r nonres --file_expr "<mass[F]>_ctthh_<ctthh[P]>" --config /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/configs/task_options/HEFT_nonres_v1.yaml --parallel -1 --unblind

# %%
start = time.time()
for parameter in commands:
    for sub_command in commands[parameter]:
        # !{sub_command}
end = time.time()
# Out:
# RooFit v3.60 -- Developed by Wouter Verkerke and David Kirkby
#                 Copyright (C) 2000-2013 NIKHEF, University of California & Stanford University
#                 All rights reserved, please read http://roofit.sourceforge.net/license.txt
#
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n1p2.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n1p2.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n1p2.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n1p2.root -d obsData
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n1p1.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n1p1.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n1p1.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n1p1.root -d obsData
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n1p0.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n1p0.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n1p0.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n1p0.root -d obsData
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n0p9.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p9.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n0p9.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p9.root -d obsData
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n1p2.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n1p2.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n1p1.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n1p1.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n1p0.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n1p0.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p9.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n0p9.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n0p8.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p8.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n0p8.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p8.root -d obsData
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n0p7.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p7.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n0p7.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p7.root -d obsData
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n0p6.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p6.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n0p6.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p6.root -d obsData
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p8.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n0p8.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p6.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n0p6.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p7.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n0p7.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n0p5.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p5.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n0p5.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p5.root -d obsData
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p5.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n0p5.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n0p3.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p3.root
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n0p4.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p4.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n0p3.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p3.root -d obsData
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n0p4.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p4.root -d obsData
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p3.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n0p3.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p4.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n0p4.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n1p2.xml
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n0p3.xml
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n1p1.xml
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n0p4.xml
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_n1p2.root exists, skip rescaling
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_n0p3.root exists, skip rescaling
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n0p15.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p15.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n0p15.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p15.root -d obsData
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p15.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n0p15.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_n1p1.root exists, skip rescaling
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n0p1.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p1.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n0p1.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p1.root -d obsData
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n0p5.xml
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n0p2.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p2.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n0p2.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p2.root -d obsData
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p1.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n0p1.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p2.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n0p2.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_n0p5.root exists, skip rescaling
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n0p05.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p05.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_n0p05.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p05.root -d obsData
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_n0p4.root exists, skip rescaling
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p0.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p0.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p0.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p0.root -d obsData
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_n0p05.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n0p05.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n0p8.xml
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p0.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p0.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_n0p8.root exists, skip rescaling
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p05.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p05.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p05.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p05.root -d obsData
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p05.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p05.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n0p7.xml
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_n0p7.root exists, skip rescaling
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p1.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p1.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p1.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p1.root -d obsData
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p1.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p1.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n0p6.xml
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n1p0.xml
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n0p9.xml
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_n0p6.root exists, skip rescaling
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p15.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p15.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p15.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p15.root -d obsData
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p15.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p15.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_n1p0.root exists, skip rescaling
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p2.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p2.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p2.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p2.root -d obsData
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p2.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p2.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_n0p9.root exists, skip rescaling
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p25.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p25.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p25.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p25.root -d obsData
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p25.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p25.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p0.xml
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_0p0.root exists, skip rescaling
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p3.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p3.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p3.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p3.root -d obsData
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p3.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p3.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n0p1.xml
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_n0p1.root exists, skip rescaling
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p35.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p35.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p35.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p35.root -d obsData
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p35.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p35.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n0p05.xml
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_n0p05.root exists, skip rescaling
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p4.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p4.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p4.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p4.root -d obsData
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p4.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p4.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n0p2.xml
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_n0p2.root exists, skip rescaling
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p5.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p5.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p5.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p5.root -d obsData
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p5.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p5.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_n0p15.xml
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_n0p15.root exists, skip rescaling
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p6.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p6.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p6.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p6.root -d obsData
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p6.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p6.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p05.xml
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_0p05.root exists, skip rescaling
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p7.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p7.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p7.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p7.root -d obsData
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p7.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p7.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p2.xml
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_0p2.root exists, skip rescaling
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p8.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p8.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p8.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p8.root -d obsData
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p25.xml
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p8.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p8.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_0p25.root exists, skip rescaling
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p9.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p9.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_0p9.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p9.root -d obsData
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p1.xml
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_0p9.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p9.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_0p1.root exists, skip rescaling
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_1p0.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_1p0.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_1p0.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_1p0.root -d obsData
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p15.xml
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_1p0.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_1p0.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_0p15.root exists, skip rescaling
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_1p1.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_1p1.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_1p1.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_1p1.root -d obsData
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_1p1.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_1p1.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p35.xml
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_0p35.root exists, skip rescaling
# INFO: Regularising /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_1p2.root --> /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_1p2.root
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w decorate -f /eos/atlas/atlascerngroupdisk/phys-hdbs/diHiggs/combination/FullRun2Workspaces/original/PUBHEFT2022/20220301_HEFT_newCDI/cgghh/bbtautau/nonres/0_cgghh_1p2.root -p /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_1p2.root -d obsData
# Skip: regularisation output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/regularised/nonres/bbtautau/0_cgghh_1p2.root exists, skip regularisation
# INFO: Creating config file: /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_1p2.xml, poi: SigXsecOverSM --> xsec_br, scaling: 1.0
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p3.xml
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_0p3.root exists, skip rescaling
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p5.xml
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_0p5.root exists, skip rescaling
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p4.xml
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_0p4.root exists, skip rescaling
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p8.xml
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_0p8.root exists, skip rescaling
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p7.xml
# Skip: rescaling output /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/rescaled/nonres/bbtautau/0_cgghh_0p7.root exists, skip rescaling
# /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/submodules/workspaceCombiner/bin/manager -w organize -x /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh/cfg/rescale/nonres/bbtautau/0_cgghh_0p9.xml
# ...
# INFO: Cached limit output from /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/limits/nonres/combined/A-bbtautau_bbyy-fullcorr/mass_0_ctthh_n1p0.json
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_n0p9.root (mass=0, ctthh=-0.9)
# INFO: Cached limit output from /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/limits/nonres/combined/A-bbtautau_bbyy-fullcorr/mass_0_ctthh_n0p9.json
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_n0p8.root (mass=0, ctthh=-0.8)
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_n0p7.root (mass=0, ctthh=-0.7)
# INFO: Cached limit output from /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/limits/nonres/combined/A-bbtautau_bbyy-fullcorr/mass_0_ctthh_n0p8.json
# INFO: Cached limit output from /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/limits/nonres/combined/A-bbtautau_bbyy-fullcorr/mass_0_ctthh_n0p7.json
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_n0p6.root (mass=0, ctthh=-0.6)
# INFO: Cached limit output from /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/limits/nonres/combined/A-bbtautau_bbyy-fullcorr/mass_0_ctthh_n0p6.json
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_n0p5.root (mass=0, ctthh=-0.5)
# INFO: Cached limit output from /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/limits/nonres/combined/A-bbtautau_bbyy-fullcorr/mass_0_ctthh_n0p5.json
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_n0p4.root (mass=0, ctthh=-0.4)
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_n0p3.root (mass=0, ctthh=-0.3)
# INFO: Cached limit output from /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/limits/nonres/combined/A-bbtautau_bbyy-fullcorr/mass_0_ctthh_n0p4.json
# INFO: Cached limit output from /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/limits/nonres/combined/A-bbtautau_bbyy-fullcorr/mass_0_ctthh_n0p3.json
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_n0p2.root (mass=0, ctthh=-0.2)
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_n0p15.root (mass=0, ctthh=-0.15)
# INFO: Cached limit output from /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/limits/nonres/combined/A-bbtautau_bbyy-fullcorr/mass_0_ctthh_n0p2.json
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_n0p1.root (mass=0, ctthh=-0.1)
# INFO: Cached limit output from /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/limits/nonres/combined/A-bbtautau_bbyy-fullcorr/mass_0_ctthh_n0p15.json
# INFO: Cached limit output from /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/limits/nonres/combined/A-bbtautau_bbyy-fullcorr/mass_0_ctthh_n0p1.json
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_n0p05.root (mass=0, ctthh=-0.05)
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_0p0.root (mass=0, ctthh=0.0)
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_0p05.root (mass=0, ctthh=0.05)
# INFO: Cached limit output from /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/limits/nonres/combined/A-bbtautau_bbyy-fullcorr/mass_0_ctthh_n0p05.json
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_0p1.root (mass=0, ctthh=0.1)
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_0p15.root (mass=0, ctthh=0.15)
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_0p2.root (mass=0, ctthh=0.2)
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_0p25.root (mass=0, ctthh=0.25)
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_0p3.root (mass=0, ctthh=0.3)
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_0p35.root (mass=0, ctthh=0.35)
# INFO: Cached limit output from /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/limits/nonres/combined/A-bbtautau_bbyy-fullcorr/mass_0_ctthh_0p3.json
# INFO: Cached limit output from /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/limits/nonres/combined/A-bbtautau_bbyy-fullcorr/mass_0_ctthh_0p35.json
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_0p4.root (mass=0, ctthh=0.4)
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_0p5.root (mass=0, ctthh=0.5)
# INFO: Cached limit output from /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/limits/nonres/combined/A-bbtautau_bbyy-fullcorr/mass_0_ctthh_0p4.json
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_0p6.root (mass=0, ctthh=0.6)
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_0p7.root (mass=0, ctthh=0.7)
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_0p8.root (mass=0, ctthh=0.8)
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_0p9.root (mass=0, ctthh=0.9)
# INFO: Cached limit output from /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/limits/nonres/combined/A-bbtautau_bbyy-fullcorr/mass_0_ctthh_0p9.json
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_1p0.root (mass=0, ctthh=1.0)
# INFO: Cached limit output from /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/limits/nonres/combined/A-bbtautau_bbyy-fullcorr/mass_0_ctthh_1p0.json
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_1p1.root (mass=0, ctthh=1.1)
# INFO: Cached limit output from /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/limits/nonres/combined/A-bbtautau_bbyy-fullcorr/mass_0_ctthh_1p1.json
# INFO: Evaluating limit for the workspace /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/combined/nonres/A-bbtautau_bbyy-fullcorr/0_ctthh_1p2.root (mass=0, ctthh=1.2)
# INFO: Cached limit output from /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh/limits/nonres/combined/A-bbtautau_bbyy-fullcorr/mass_0_ctthh_1p2.json
# ^C
# Process ForkProcess-20:
# Process ForkProcess-13:
# Process ForkProcess-12:
# Process ForkProcess-19:
# Process ForkProcess-18:
#
# Aborted!
# Process ForkProcess-15:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/concurrent/futures/process.py", line 237, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/concurrent/futures/process.py", line 237, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/concurrent/futures/process.py", line 237, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/concurrent/futures/process.py", line 237, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/concurrent/futures/process.py", line 237, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/queues.py", line 103, in get
#     res = self._recv_bytes()
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/connection.py", line 221, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/concurrent/futures/process.py", line 237, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt

# %%
print(f"Total time taken: {end - start}s")
# Out:
# Total time taken: 6892.979714632034s

# %% [markdown]
# # Plot limit results

# %%
from quickstats.plots import UpperLimit2DPlot
from quickstats.utils.common_utils import combine_dict
import json
import numpy as np
import pandas as pd

# %%
parameters = ['ctthh', 'cgghh']
limit_data = {}
for parameter in parameters:
    limit_data[parameter] = {}
    outdir = os.path.join(config['outdir'], parameter)
    print(parameter, outdir)
    for channel in config['channels']:
        limit_path = os.path.join(outdir, 'limits', config['resonant_type'], channel, "limits.json")
        if not os.path.exists(limit_path):
            raise FileNotFoundError(f"file \"{limit_path}\" not found")
        limit_data[parameter][channel] = pd.DataFrame(json.load(open(limit_path))).set_index([parameter])
    combined_limit_path = os.path.join(outdir, 'limits', config['resonant_type'],
                                       "combined", "A-{}-fullcorr".format("_".join(sorted(config['channels']))),
                                       "limits.json")
    limit_data[parameter]['combined'] = pd.DataFrame(json.load(open(combined_limit_path))).set_index([parameter])
# Out:
# ctthh /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/ctthh
# cgghh /afs/cern.ch/work/z/zhangr/HHcomb/hh_combination_fw/hh_combination_fw/outputs_newCDI/cgghh

# %%
def get_coupling_xs(coupling:str, value:np.ndarray): # in fb
    if coupling == "ctthh":
        return (12.388916422*value**2 - 6.1910471095*value + 1.)*31.05
    elif coupling == "cgghh":
        return (12.6387787068*value**2 - 3.0008652812*value + 1.)*31.05
    
def get_theory_curve(coupling:str, vmin:float, vmax:float):
    x = np.linspace(vmin, vmax, 1000) 
    y = get_coupling_xs(coupling, x)
    return x, y

def get_intersections(x_data, y_data, x_theory, y_theory):
    # get the intersection between expected and theory prediction
    
    # interpolate expected limit with same number of datapoints as used in theory prediction
    interpolated_limit = np.interp(x_theory, x_data, y_data) 

    #limitm1 = n*np.array(limit_bands[0]) - 1
    limitm1 = interpolated_limit - y_theory 
    idx = np.argwhere(np.diff(np.sign(limitm1))).flatten() # determines what index intersection points are at 

    #linear interpolation to get exact intercepts: x = x1 + (x2-x1)/(y2-y1) * (y-y1)
    #y = 0 -> x = x1 - (x2-x1)/(y2-y1) * y1
    intersections = [x_theory[x] - (x_theory[x+1] - x_theory[x])/(limitm1[x+1] - limitm1[x]) * limitm1[x] for x in idx]
    return intersections

# %%
analysis_label_options = {
    'energy': '13 TeV',
    'lumi': '139 fb$^{-1}$',
    'fontsize': 30,
    'loc': (0.05, 0.95),
    'status': 'prelim' #'int',
}
styles = {
    'legend':{
        'loc': (0.6, 0.65),
        'fontsize': 16
    }
}
channel_text = {
    'bbtautau': r'$\mathrm{HH\rightarrow b\bar{b}\tau^+\tau^-}$',
    'bbyy': r'$\mathrm{HH\rightarrow b\bar{b}\gamma\gamma}$',
    'combined': r'$\mathrm{HH\rightarrow b\bar{b}\tau^+\tau^-} + b\bar{b}\gamma\gamma$'
}
ylabel = r"$\sigma_{ggF}(HH)$ [fb]"
xlabel = {
    'cgghh':"$\it{c_{gghh}}$",
    'ctthh':"$\it{c_{tthh}}$"
}
ylim = {
    'cgghh': {
        'bbyy': (4, 2e4),
        'bbtautau': (4, 2e4),
        'combined': (4, 2e4),
    },
    'ctthh': {
        'bbyy': (4, 2e4),
        'bbtautau': (4, 2e4),
        'combined': (4, 2e4),
    }
}

# %%
import matplotlib.pyplot as plt
from pdb import set_trace
def plot_limit_scan(all_data, parameter:str, channel:str, save_as:Optional[str]=None):
    data = all_data[parameter][channel]
    coupling_values = limit_data[parameter][channel].index.astype(float).values
    coupling_xs = get_coupling_xs(parameter, coupling_values)
    label_options = {**analysis_label_options, 'extra_text': channel_text[channel]}
    plotter = UpperLimit2DPlot(data, scale_factor=coupling_xs,
                               analysis_label_options=label_options,
                               styles=styles)
    coupling_values_theory, coupling_xs_theory = get_theory_curve(parameter, min(coupling_values), max(coupling_values))
    plotter.add_highlight(0, get_coupling_xs(parameter, 0), label="SM prediction")
    plotter.add_curve(coupling_values_theory, coupling_xs_theory,  label="Theory prediction")
    ax = plotter.draw(xlabel=xlabel[parameter], ylabel=ylabel, log=True, draw_observed=True,
                      xlim=(min(coupling_values), max(coupling_values)),
                      ylim=ylim[parameter][channel], observed_marker=None)
    
    # get intersections
    exp_ints = get_intersections(coupling_values, coupling_xs*data['0'], 
                                 coupling_values_theory, coupling_xs_theory)
    obs_ints = get_intersections(coupling_values, coupling_xs*data['obs'], 
                             coupling_values_theory, coupling_xs_theory)
    coupling_latex = xlabel[parameter].replace("$", "")
    ax.annotate(r'Expected: ${} \in [{:.1f}, {:.1f}]$'.format(coupling_latex, exp_ints[0], exp_ints[1]),
                (0.03, 0.08), xycoords = 'axes fraction', fontsize = 20)
    ax.annotate(r'Observed: ${} \in [{:.1f}, {:.1f}]$'.format(coupling_latex, obs_ints[0], obs_ints[1]),
                (0.03, 0.15), xycoords = 'axes fraction', fontsize = 20)
    if save_as is not None:
        plt.savefig(save_as, bbox_inches="tight")
        data.to_csv(save_as.replace('pdf', 'csv'))
        with open(save_as.replace('pdf', 'json'), 'w') as fp:
            json.dump(data.to_dict("index"), fp, indent=2)
    return exp_ints, obs_ints

# %%
plot_outdir = os.path.join(config['outdir'], 'plots')
if not os.path.exists(plot_outdir):
    os.makedirs(plot_outdir)

# %%
interval = {}
latex_string = {}
for parameter in limit_data:
    for channel in limit_data[parameter]:
        save_path = os.path.join(plot_outdir, f'{channel}_{parameter}_limit_scan.pdf')
        exp_ints, obs_ints = plot_limit_scan(limit_data, parameter, channel, save_as=save_path)
        print(parameter, channel, 'exp', exp_ints, 'obs', obs_ints)
        exp_ints = [float(f"{i:.1f}") for i in exp_ints]
        obs_ints = [float(f"{i:.1f}") for i in obs_ints]
        latex_string[f"{parameter}-{channel}-exp"] = str(exp_ints)
        latex_string[f"{parameter}-{channel}-obs"] = str(obs_ints)
        plt.show()
# Out:
# ctthh bbyy exp [-0.39476781829859897, 0.8638204145238039] obs [-0.29821977828454643, 0.7559513602639]
# ctthh bbtautau exp [-0.23657917420383176, 0.632802911703564] obs [-0.2864468617355561, 0.6946051395989129]
# ctthh combined exp [-0.19332219582392415, 0.6059756971347607] obs [-0.19643358683753015, 0.6235477721051302]
# cgghh bbyy exp [-0.5205389850152659, 0.6525955347427358] obs [-0.41239769185423847, 0.5304518899420996]
# cgghh bbtautau exp [-0.36141135033870747, 0.37182361256051255] obs [-0.4203128495963963, 0.44575968448833464]
# cgghh combined exp [-0.3097459034661957, 0.34539154891270274] obs [-0.3108619668514678, 0.3712971085011329]

# %%
def format_latex():
    couplings = ['gghh', 'tthh']
    strings = []
    for coupling in couplings:
        strings.append("$c_{" + coupling + "}$ & $" + latex_string[f'c{coupling}-bbyy-obs'] + '$ & $' + latex_string[f'c{coupling}-bbyy-exp'] +\
            '$ & $' + latex_string[f'c{coupling}-bbtautau-obs'] + '$ & $' + latex_string[f'c{coupling}-bbtautau-exp'] +\
            '$ & $' + latex_string[f'c{coupling}-combined-obs'] + '$ & $' + latex_string[f'c{coupling}-combined-exp'] + r'$ \\')
        
    for coupling in couplings:
        for i in ['exp', 'obs']:
            strings.append(r'\newcommand*{\c' + coupling + r'combined' + i + r'left}{\num{' + latex_string[f'c{coupling}-combined-{i}'].split(',')[0].split('[')[-1] + r'}\xspace}')
            strings.append(r'\newcommand*{\c' + coupling + r'combined' + i + r'right}{\num{' + latex_string[f'c{coupling}-combined-{i}'].split(',')[-1].split(']')[0] + r'}\xspace}')
    save_path = os.path.join(plot_outdir, 'scan.tex')
    strings = '\n'.join(strings)
    with open(save_path, "w") as text_file:
        text_file.write(strings)
    print(strings)
# Out:
# $c_{gghh}$ & $[-0.4, 0.5]$ & $[-0.5, 0.7]$ & $[-0.4, 0.4]$ & $[-0.4, 0.4]$ & $[-0.3, 0.4]$ & $[-0.3, 0.3]$ \\
# $c_{tthh}$ & $[-0.3, 0.8]$ & $[-0.4, 0.9]$ & $[-0.3, 0.7]$ & $[-0.2, 0.6]$ & $[-0.2, 0.6]$ & $[-0.2, 0.6]$ \\
# \newcommand*{\cgghhcombinedexpleft}{\num{-0.3}\xspace}
# \newcommand*{\cgghhcombinedexpright}{\num{ 0.3}\xspace}
# \newcommand*{\cgghhcombinedobsleft}{\num{-0.3}\xspace}
# \newcommand*{\cgghhcombinedobsright}{\num{ 0.4}\xspace}
# \newcommand*{\ctthhcombinedexpleft}{\num{-0.2}\xspace}
# \newcommand*{\ctthhcombinedexpright}{\num{ 0.6}\xspace}
# \newcommand*{\ctthhcombinedobsleft}{\num{-0.2}\xspace}
# \newcommand*{\ctthhcombinedobsright}{\num{ 0.6}\xspace}

# %%
format_latex()
# Out:
# $c_{gghh}$ & $[-0.4, 0.5]$ & $[-0.5, 0.7]$ & $[-0.4, 0.4]$ & $[-0.4, 0.4]$ & $[-0.3, 0.4]$ & $[-0.3, 0.3]$ \\
# $c_{tthh}$ & $[-0.3, 0.8]$ & $[-0.4, 0.9]$ & $[-0.3, 0.7]$ & $[-0.2, 0.6]$ & $[-0.2, 0.6]$ & $[-0.2, 0.6]$ \\
# \newcommand*{\cgghhcombinedexpleft}{\num{-0.3}\xspace}
# \newcommand*{\cgghhcombinedexpright}{\num{ 0.3}\xspace}
# \newcommand*{\cgghhcombinedobsleft}{\num{-0.3}\xspace}
# \newcommand*{\cgghhcombinedobsright}{\num{ 0.4}\xspace}
# \newcommand*{\ctthhcombinedexpleft}{\num{-0.2}\xspace}
# \newcommand*{\ctthhcombinedexpright}{\num{ 0.6}\xspace}
# \newcommand*{\ctthhcombinedobsleft}{\num{-0.2}\xspace}
# \newcommand*{\ctthhcombinedobsright}{\num{ 0.6}\xspace}

# %%
decorrelate_gghh
# Out:
#        mass         0         2         1        -1        -2       obs  inj
# cgghh
# -1.20     0  0.104806  0.228996  0.154036  0.075518  0.056252  0.111359    0
# -1.10     0  0.123719  0.270022  0.181658  0.089146  0.066403  0.131097    0
# -1.00     0  0.147978  0.322903  0.217273  0.106626  0.079424  0.156400    0
# -0.90     0  0.179950  0.392546  0.264200  0.129664  0.096584  0.189575    0
# -0.80     0  0.222985  0.486217  0.327353  0.160673  0.119682  0.234102    0
# -0.70     0  0.283253  0.617294  0.415758  0.204099  0.152029  0.296732    0
# -0.60     0  0.370114  0.806106  0.543152  0.266688  0.198650  0.385274    0
# -0.50     0  0.500846  1.089204  0.734321  0.360887  0.268817  0.516665    0
# -0.40     0  0.706194  1.534268  1.035216  0.508852  0.379033  0.720423    0
# -0.30     0  1.040052  2.257068  1.524322  0.749415  0.558223  1.042839    0
# -0.20     0  1.588227  3.441003  2.326227  1.144405  0.852442  1.562661    0
# -0.15     0  1.956696  4.236106  2.865194  1.409908  1.050209  1.909679    0
# -0.10     0  2.374226  5.139873  3.476807  1.710761  1.274308  2.303544    0
# -0.05     0  2.759308  5.975615  4.041490  1.988234  1.480992  2.683516    0
#  0.00     0  2.990856  6.485891  4.383278  2.155077  1.605269  2.947712    0
#  0.05     0  2.967734  6.450990  4.353559  2.138417  1.592859  2.997038    0
#  0.10     0  2.693258  5.872748  3.956148  1.940642  1.445541  2.798052    0
#  0.15     0  2.281773  4.989020  3.355605  1.644144  1.224686  2.423460    0
#  0.20     0  1.865443  4.088356  2.745896  1.344155  1.001231  2.016916    0
#  0.25     0  1.500403  3.294062  2.210013  1.081124  0.805305  1.641625    0
#  0.30     0  1.206924  2.654808  1.779802  0.869656  0.647787  1.330714    0
#  0.35     0  0.980715  2.154897  1.444111  0.706659  0.526375  1.086830    0
#  0.40     0  0.804499  1.769312  1.185385  0.579686  0.431795  0.893830    0
#  0.50     0  0.560872  1.233253  0.826082  0.404139  0.301035  0.623876    0
#  0.60     0  0.408362  0.898285  0.601734  0.294248  0.219179  0.454328    0
#  0.70     0  0.308667  0.678730  0.454744  0.222412  0.165669  0.343084    0
#  0.80     0  0.240957  0.529594  0.354891  0.173623  0.129328  0.267451    0
#  0.90     0  0.192772  0.423536  0.283852  0.138903  0.103465  0.213681    0
#  1.00     0  0.157514  0.345953  0.231886  0.113497  0.084542  0.174369    0
#  1.10     0  0.130959  0.287536  0.192752  0.094363  0.070289  0.144813    0
#  1.20     0  0.110419  0.242609  0.162656  0.079563  0.059264  0.121801    0

# %%
gghh = pd.concat([correlate_gghh[['0', 'obs']], decorrelate_gghh[['0', 'obs']], \
                  (correlate_gghh[['0', 'obs']]/decorrelate_gghh[['0', 'obs']] - 1) * 100], axis=1)
gghh.columns = ['corr exp','corr obs', 'uncorr exp', 'uncorr obs', 'diff exp %', 'diff obs %']
gghh
# Out:
#        corr exp  corr obs  uncorr exp  uncorr obs  diff exp %  diff obs %
# cgghh
# -1.20  0.105415  0.112312    0.104221    0.110476    1.145876    1.661582
# -1.10  0.124345  0.132184    0.122907    0.130020    1.170197    1.663700
# -1.00  0.148882  0.157724    0.147001    0.155127    1.279215    1.674221
# -0.90  0.181061  0.191215    0.178749    0.188061    1.293223    1.677107
# -0.80  0.224384  0.236137    0.221489    0.232245    1.307027    1.675774
# -0.70  0.285061  0.299318    0.281325    0.293535    1.327801    1.969976
# -0.60  0.372541  0.388664    0.367543    0.382160    1.359785    1.701968
# -0.50  0.504313  0.521265    0.497231    0.512471    1.424189    1.716032
# -0.40  0.711273  0.727539    0.701003    0.714462    1.465035    1.830355
# -0.30  1.047882  1.053363    1.031556    1.034291    1.582726    1.843920
# -0.20  1.601115  1.577681    1.575894    1.549991    1.600405    1.786454
# -0.15  1.973049  1.928121    1.941449    1.894233    1.627641    1.789008
# -0.10  2.394522  2.326126    2.355667    2.285079    1.649422    1.796297
# -0.05  2.783013  2.710096    2.737850    2.662099    1.649582    1.802953
#  0.00  3.015563  2.976841    2.968088    2.924015    1.599501    1.806653
#  0.05  2.990306  3.034211    2.946111    2.980421    1.500115    1.804796
#  0.10  2.711517  2.827033    2.674922    2.775806    1.368092    1.845468
#  0.15  2.295343  2.447621    2.267449    2.404273    1.230179    1.802951
#  0.20  1.875468  2.034743    1.854539    2.000666    1.128527    1.703292
#  0.25  1.507883  1.655461    1.492115    1.629161    1.056779    1.614303
#  0.30  1.212547  1.341613    1.200609    1.320166    0.994305    1.624573
#  0.35  0.985133  1.096844    0.975703    1.078598    0.966464    1.691635
#  0.40  0.808175  0.901945    0.800332    0.887066    0.980020    1.677233
#  0.50  0.563433  0.628931    0.557960    0.619124    0.980818    1.584045
#  0.60  0.410203  0.457999    0.406266    0.450878    0.969090    1.579445
#  0.70  0.310082  0.346137    0.307072    0.340468    0.980453    1.665238
#  0.80  0.242071  0.269859    0.239697    0.265398    0.990627    1.680710
#  0.90  0.193671  0.215602    0.191747    0.212033    1.003309    1.683397
#  1.00  0.158258  0.175425    0.156670    0.173030    1.013698    1.383652
#  1.10  0.131451  0.145679    0.130250    0.143698    0.922064    1.378888
#  1.20  0.110934  0.122783    0.109928    0.121159    0.915303    1.340056

# %%
tthh = pd.concat([correlate_tthh[['0', 'obs']], decorrelate_tthh[['0', 'obs']], \
                  (correlate_tthh[['0', 'obs']]/decorrelate_tthh[['0', 'obs']] - 1) * 100], axis=1)
tthh.columns = ['corr exp','corr obs', 'uncorr exp', 'uncorr obs', 'diff exp %', 'diff obs %']
tthh
# Out:
#        corr exp  corr obs  uncorr exp  uncorr obs  diff exp %  diff obs %
# ctthh
# -1.20  0.090188  0.093924    0.089914    0.093560    0.305820    0.389899
# -1.10  0.104359  0.108591    0.104038    0.108169    0.308111    0.390194
# -1.00  0.122135  0.126964    0.121758    0.126470    0.309670    0.390508
# -0.90  0.144840  0.150396    0.144387    0.149811    0.313560    0.390867
# -0.80  0.174458  0.180910    0.173917    0.180205    0.311178    0.391310
# -0.70  0.214164  0.221680    0.213611    0.220816    0.259037    0.391503
# -0.60  0.269046  0.277783    0.268181    0.276699    0.322448    0.391768
# -0.50  0.347586  0.358043    0.346464    0.356640    0.323710    0.393346
# -0.40  0.465187  0.477738    0.463682    0.475860    0.324481    0.394666
# -0.30  0.652504  0.667160    0.650367    0.664533    0.328642    0.395328
# -0.20  0.974724  0.990154    0.971488    0.986260    0.333139    0.394776
# -0.15  1.226449  1.239426    1.222338    1.234508    0.336270    0.398406
# -0.10  1.584695  1.592724    1.579374    1.586385    0.336948    0.399539
# -0.05  2.107522  2.103447    2.100191    2.095057    0.349080    0.400490
#  0.00  2.892117  2.867291    2.881874    2.854213    0.355431    0.458202
#  0.05  4.084645  4.024342    4.069930    4.007953    0.361556    0.408900
#  0.10  5.836029  5.733562    5.814870    5.710136    0.363877    0.410257
#  0.15  7.958465  7.895372    7.930256    7.863174    0.355713    0.409479
#  0.20  9.307855  9.530009    9.277719    9.492162    0.324820    0.398718
#  0.25  8.500524  9.022415    8.477008    8.987822    0.277409    0.384890
#  0.30  6.407892  6.968028    6.392324    6.942258    0.243544    0.371211
#  0.35  4.493351  4.928199    4.483006    4.910265    0.230776    0.365228
#  0.40  3.160005  3.465817    3.152750    3.453226    0.230125    0.364615
#  0.50  1.700423  1.854642    1.696384    1.847860    0.238116    0.366985
#  0.60  1.030095  1.117089    1.027607    1.112971    0.242126    0.369945
#  0.70  0.683435  0.737189    0.681694    0.734454    0.255477    0.372411
#  0.80  0.483493  0.519650    0.482232    0.517712    0.261601    0.374313
#  0.90  0.359207  0.384889    0.358247    0.383449    0.267915    0.375524
#  1.00  0.277409  0.296503    0.276652    0.295390    0.273364    0.376714
#  1.10  0.220110  0.234936    0.219636    0.234053    0.215779    0.377561
#  1.20  0.178860  0.190618    0.178371    0.189900    0.274114    0.378476
