# %%
from quickstats.components import ExtendedModel
import atlasplots as aplt
import numpy as np
import ROOT
model = ExtendedModel("/afs/ihep.ac.cn/users/c/cyz/besfs/HH_comb/hh_combination_fw_new/run_heft_final/output/workspace/heft/bbbb/0_fit.root", data_name="combData",verbosity="ERROR")
pdf = model.pdf
data = model.data
nuis = model.get_constrained_nuisance_parameters()
cat_map = model.get_category_map()
def get_roorealvar_values(var):
    min_val = var.getMin()
    max_val = var.getMax()
    num_bins = var.getBins()
    bin_width = (max_val - min_val) / num_bins
    values = [min_val + (i + 0.5) * bin_width for i in range(num_bins)]
    return values

# %%
all_constraints = model.get_all_constraints()
model.save_snapshot("prefit_nuis",nuis)
model.save_snapshot("prefit_glob",model.global_observables)
output_path = "bbbb_prefit.root"
fo = ROOT.TFile(output_path,"RECREATE")

for cat in cat_map:
    cat_pdf = model.workspace.pdf(cat+"_model")
    if len(cat_map[cat]["observables"].keys())==1:
        observable = model.workspace.obj(list(cat_map[cat]["observables"].keys())[0])
    else:
        print("More than one observable in category, not supported yet")
        continue
    hist_pdf = ROOT.TH1F(cat, cat, observable.getBins(), observable.getMin(), observable.getMax())
    hist_pdf_syst_up,hist_pdf_syst_down = {},{}
    for nui in model.nuisance_parameters:
        nui_name = nui.GetName()
        if 'gamma_' in nui_name and cat not in nui_name: continue
        hist_pdf_syst_up[nui_name] = ROOT.TH1F(cat+"_"+nui_name+"_up", cat+"_"+nui_name+"_up", observable.getBins(), observable.getMin(), observable.getMax())
        hist_pdf_syst_down[nui_name] = ROOT.TH1F(cat+"_"+nui_name+"_down", cat+"_"+nui_name+"_down", observable.getBins(), observable.getMin(), observable.getMax())
    xs = get_roorealvar_values(observable)
    for i,x in enumerate(xs):
        observable.setVal(x)
        hist_pdf.SetBinContent(i+1, cat_pdf.getVal())
    for nui in model.nuisance_parameters:
        nui_name = nui.GetName()
        if nui_name not in hist_pdf_syst_up.keys(): continue
        if 'gamma_' in nui_name:
            prefit_variation, _, nuis_nom = model.inspect_constrained_nuisance_parameter(nui, all_constraints)
        else:
            prefit_variation = 1
            nuis_nom = 0
        nui.setVal(nuis_nom+prefit_variation)
        for i,x in enumerate(xs):
            observable.setVal(x)
            hist_pdf_syst_up[nui_name].SetBinContent(i+1, cat_pdf.getValV())
        nui.setVal(nuis_nom-prefit_variation)
        for i,x in enumerate(xs):
            observable.setVal(x)
            hist_pdf_syst_down[nui_name].SetBinContent(i+1, cat_pdf.getValV())
        nui.setVal(nuis_nom)

    fo.cd()
    hist_pdf.Write()
    for nui in hist_pdf_syst_up:
        hist_pdf_syst_up[nui].Write()
        hist_pdf_syst_down[nui].Write()

fo.Close()
print("Save to",output_path)
# Out:
# Save to bbbb_prefit.root

# %%
model.load_snapshot("chhh_fit")

output_path = "bbbb_postfit.root"
fo = ROOT.TFile(output_path,"RECREATE")

for cat in cat_map:
    cat_pdf = model.workspace.pdf(cat+"_model")
    if len(cat_map[cat]["observables"].keys())==1:
        observable = model.workspace.obj(list(cat_map[cat]["observables"].keys())[0])
    else:
        print("More than one observable in category, not supported yet")
        continue
    hist_pdf = ROOT.TH1F(cat, cat, observable.getBins(), observable.getMin(), observable.getMax())
    hist_pdf_syst_up,hist_pdf_syst_down = {},{}
    for nui in model.nuisance_parameters:
        nui_name = nui.GetName()
        if 'gamma_' in nui_name and cat not in nui_name: continue
        hist_pdf_syst_up[nui_name] = ROOT.TH1F(cat+"_"+nui_name+"_up", cat+"_"+nui_name+"_up", observable.getBins(), observable.getMin(), observable.getMax())
        hist_pdf_syst_down[nui_name] = ROOT.TH1F(cat+"_"+nui_name+"_down", cat+"_"+nui_name+"_down", observable.getBins(), observable.getMin(), observable.getMax())
    xs = get_roorealvar_values(observable)
    for i,x in enumerate(xs):
        observable.setVal(x)
        hist_pdf.SetBinContent(i+1, cat_pdf.getVal())
    for nui in model.nuisance_parameters:
        nui_name = nui.GetName()
        if nui_name not in hist_pdf_syst_up.keys(): continue
        nuis_nom = nui.getVal()
        postfit_variation = nui.getError()
        print(cat,nui_name,nuis_nom,postfit_variation)
        nui.setVal(nuis_nom+postfit_variation)
        for i,x in enumerate(xs):
            observable.setVal(x)
            hist_pdf_syst_up[nui_name].SetBinContent(i+1, cat_pdf.getValV())
        nui.setVal(nuis_nom-postfit_variation)
        for i,x in enumerate(xs):
            observable.setVal(x)
            hist_pdf_syst_down[nui_name].SetBinContent(i+1, cat_pdf.getValV())
        nui.setVal(nuis_nom)
        
    fo.cd()
    hist_pdf.Write()
    for nui in hist_pdf_syst_up:
        hist_pdf_syst_up[nui].Write()
        hist_pdf_syst_down[nui].Write()

fo.Close()
print("Save to",output_path)
# Out:
# ggf_16_dEta_1_Xhh_1 alpha_ATLAS_LUMI_Run2 0.004567525212783559 0.9917644863989754
# ggf_16_dEta_1_Xhh_1 alpha_CR12_shape_E_ggf_16 2.168539533515497 0.6393014883246642
# ggf_16_dEta_1_Xhh_1 alpha_CR12_shape_E_ggf_17 0.497043499554196 0.6882252143417914
# ggf_16_dEta_1_Xhh_1 alpha_CR12_shape_E_ggf_18 0.25524582956042013 0.6688614977918013
# ggf_16_dEta_1_Xhh_1 alpha_CR12_shape_N_ggf_16 -0.44872927520638145 0.7275321766705052
# ggf_16_dEta_1_Xhh_1 alpha_CR12_shape_N_ggf_17 -1.1801691137968153 0.5845741671674937
# ggf_16_dEta_1_Xhh_1 alpha_CR12_shape_N_ggf_18 -1.2579905172800019 0.5543985845383885
# ggf_16_dEta_1_Xhh_1 alpha_CR12_shape_S_ggf_16 1.8688634907203252 0.7184404278731231
# ggf_16_dEta_1_Xhh_1 alpha_CR12_shape_S_ggf_17 0.5707631751216246 0.6362628351894568
# ggf_16_dEta_1_Xhh_1 alpha_CR12_shape_S_ggf_18 0.477832857918434 0.8506288349618056
# ggf_16_dEta_1_Xhh_1 alpha_CR12_shape_W_ggf_16 0.09445340939062155 0.7414250030312819
# ggf_16_dEta_1_Xhh_1 alpha_CR12_shape_W_ggf_17 -0.09077454768037152 0.5077296400511733
# ggf_16_dEta_1_Xhh_1 alpha_CR12_shape_W_ggf_18 -0.9698305485694023 0.7464106283545502
# ggf_16_dEta_1_Xhh_1 alpha_FT_EFF_Eigen_B_0 -0.041427059914034885 0.9952045455677045
# ggf_16_dEta_1_Xhh_1 alpha_FT_EFF_Eigen_B_1 0.0009777333916646163 0.9900873403742273
# ggf_16_dEta_1_Xhh_1 alpha_FT_EFF_Eigen_B_2 0.022460706049268128 0.993556655640294
# ggf_16_dEta_1_Xhh_1 alpha_FT_EFF_Eigen_C_0 -0.0002046586927998812 0.9933466842607453
# ggf_16_dEta_1_Xhh_1 alpha_FT_EFF_Eigen_C_1 -5.50421824863259e-05 0.9933526219051745
# ggf_16_dEta_1_Xhh_1 alpha_FT_EFF_Eigen_C_2 3.557299177397435e-05 0.9933525247386102
# ggf_16_dEta_1_Xhh_1 alpha_FT_EFF_Eigen_C_3 -7.841183711687107e-06 0.9933524528929045
# ggf_16_dEta_1_Xhh_1 alpha_FT_EFF_Eigen_Light_0 8.345396658282402e-05 0.9933472359120243
# ggf_16_dEta_1_Xhh_1 alpha_FT_EFF_Eigen_Light_1 7.354596273454394e-05 0.9933524684752388
# ggf_16_dEta_1_Xhh_1 alpha_FT_EFF_Eigen_Light_2 -5.1503590978939015e-05 0.9933524330546835
# ggf_16_dEta_1_Xhh_1 alpha_FT_EFF_Eigen_Light_3 6.8543316226639395e-06 0.993352450526747
# ggf_16_dEta_1_Xhh_1 alpha_FT_EFF_extrapolation 0.0002995225584614893 0.9933188850151786
# ggf_16_dEta_1_Xhh_1 alpha_FT_EFF_extrapolation_from_charm -2.3700177398363557e-05 0.9933524791126707
# ggf_16_dEta_1_Xhh_1 alpha_HEFT_RW_SYST_lo_hi_mhh 0.015438172211627514 0.988938140234189
# ggf_16_dEta_1_Xhh_1 alpha_JET_BJES_Response -0.010344849621233138 0.7456243376355012
# ggf_16_dEta_1_Xhh_1 alpha_JET_EffectiveNP_Detector1 -0.006118074186670269 0.9712940436434903
# ggf_16_dEta_1_Xhh_1 alpha_JET_EffectiveNP_Detector2 -0.0017050121282824607 0.9933902063028721
# ggf_16_dEta_1_Xhh_1 alpha_JET_EffectiveNP_Mixed1 -0.0039006067541191244 0.9102881810271476
# ggf_16_dEta_1_Xhh_1 alpha_JET_EffectiveNP_Mixed2 0.0012356886607076691 0.8562188150465315
# ggf_16_dEta_1_Xhh_1 alpha_JET_EffectiveNP_Mixed3 -0.005192323406649639 0.9996447766384449
# ggf_16_dEta_1_Xhh_1 alpha_JET_EffectiveNP_Modelling1 -0.03203703603659376 0.7579716677292108
# ggf_16_dEta_1_Xhh_1 alpha_JET_EffectiveNP_Modelling2 -0.004686992653220829 0.9750758658485987
# ggf_16_dEta_1_Xhh_1 alpha_JET_EffectiveNP_Modelling3 0.009263209442878007 0.9462984743422221
# ggf_16_dEta_1_Xhh_1 alpha_JET_EffectiveNP_Modelling4 -0.005329172323236179 0.9873946603026198
# ggf_16_dEta_1_Xhh_1 alpha_JET_EffectiveNP_Statistical1 0.00016233150076076092 0.9748334245438499
# ggf_16_dEta_1_Xhh_1 alpha_JET_EffectiveNP_Statistical2 0.001015707489221614 0.9787335903579253
# ggf_16_dEta_1_Xhh_1 alpha_JET_EffectiveNP_Statistical3 -0.0002868243171746951 0.9716371413911022
# ggf_16_dEta_1_Xhh_1 alpha_JET_EffectiveNP_Statistical4 -0.007830749980144443 0.9755774085713431
# ggf_16_dEta_1_Xhh_1 alpha_JET_EffectiveNP_Statistical5 0.005128399471892237 1.0047883346469781
# ggf_16_dEta_1_Xhh_1 alpha_JET_EffectiveNP_Statistical6 -0.007344630760645633 0.9940612460363729
# ggf_16_dEta_1_Xhh_1 alpha_JET_EtaIntercalibration_Modelling -0.015458487987202256 0.8047512121588433
# ggf_16_dEta_1_Xhh_1 alpha_JET_EtaIntercalibration_NonClosure_2018data -0.004883953591743286 1.0380558241633984
# ggf_16_dEta_1_Xhh_1 alpha_JET_EtaIntercalibration_NonClosure_highE -1.719483409822831e-05 0.9932824487927487
# ggf_16_dEta_1_Xhh_1 alpha_JET_EtaIntercalibration_NonClosure_negEta 5.120443027299476e-05 1.0061878033463163
# ggf_16_dEta_1_Xhh_1 alpha_JET_EtaIntercalibration_NonClosure_posEta 0.001746870036075863 0.9861331116992589
# ggf_16_dEta_1_Xhh_1 alpha_JET_EtaIntercalibration_TotalStat -0.00947523540750922 0.9634657860081906
# ggf_16_dEta_1_Xhh_1 alpha_JET_Flavor_Composition -0.014789638706064822 0.9584122008370903
# ggf_16_dEta_1_Xhh_1 alpha_JET_Flavor_Response 0.004593728146261699 0.956352175158389
# ggf_16_dEta_1_Xhh_1 alpha_JET_JER_DataVsMC_MC16 0.010491992731881842 0.8445510252569917
# ggf_16_dEta_1_Xhh_1 alpha_JET_JER_EffectiveNP_1 0.030419452409371234 0.7045794727286467
# ggf_16_dEta_1_Xhh_1 alpha_JET_JER_EffectiveNP_10 -0.02098192224263878 0.9793936260667258
# ggf_16_dEta_1_Xhh_1 alpha_JET_JER_EffectiveNP_11 -0.015863810471495123 0.8796117766774343
# ggf_16_dEta_1_Xhh_1 alpha_JET_JER_EffectiveNP_12restTerm -0.03970503477113964 0.8614482934662158
# ggf_16_dEta_1_Xhh_1 alpha_JET_JER_EffectiveNP_2 0.046670720773407566 0.9713152825608283
# ggf_16_dEta_1_Xhh_1 alpha_JET_JER_EffectiveNP_3 0.01624105138125343 1.2179678953822974
# ggf_16_dEta_1_Xhh_1 alpha_JET_JER_EffectiveNP_4 0.030053065999980946 0.9899338384340421
# ggf_16_dEta_1_Xhh_1 alpha_JET_JER_EffectiveNP_5 -0.049850507454804155 1.0099865161208732
# ggf_16_dEta_1_Xhh_1 alpha_JET_JER_EffectiveNP_6 -0.001699012392611745 0.929601904722595
# ggf_16_dEta_1_Xhh_1 alpha_JET_JER_EffectiveNP_7 -0.052159294601997086 1.0062611013567446
# ggf_16_dEta_1_Xhh_1 alpha_JET_JER_EffectiveNP_8 -0.004357362359565235 0.963216184745399
# ggf_16_dEta_1_Xhh_1 alpha_JET_JER_EffectiveNP_9 -0.056007978930007626 0.8893604029353841
# ggf_16_dEta_1_Xhh_1 alpha_JET_JVT 0.004332085513117571 0.9927367227372768
# ggf_16_dEta_1_Xhh_2 alpha_FT_EFF_extrapolation_from_charm -2.3700177398363557e-05 0.9933524791126707
# ggf_16_dEta_1_Xhh_2 alpha_HEFT_RW_SYST_lo_hi_mhh 0.015438172211627514 0.988938140234189
# ggf_16_dEta_1_Xhh_2 alpha_JET_BJES_Response -0.010344849621233138 0.7456243376355012
# ggf_16_dEta_1_Xhh_2 alpha_JET_EffectiveNP_Detector1 -0.006118074186670269 0.9712940436434903
# ggf_16_dEta_1_Xhh_2 alpha_JET_EffectiveNP_Detector2 -0.0017050121282824607 0.9933902063028721
# ggf_16_dEta_1_Xhh_2 alpha_JET_EffectiveNP_Mixed1 -0.0039006067541191244 0.9102881810271476
# ggf_16_dEta_1_Xhh_2 alpha_JET_EffectiveNP_Mixed2 0.0012356886607076691 0.8562188150465315
# ggf_16_dEta_1_Xhh_2 alpha_JET_EffectiveNP_Mixed3 -0.005192323406649639 0.9996447766384449
# ggf_16_dEta_1_Xhh_2 alpha_JET_EffectiveNP_Modelling1 -0.03203703603659376 0.7579716677292108
# ggf_16_dEta_1_Xhh_2 alpha_JET_EffectiveNP_Modelling2 -0.004686992653220829 0.9750758658485987
# ggf_16_dEta_1_Xhh_2 alpha_JET_EffectiveNP_Modelling3 0.009263209442878007 0.9462984743422221
# ggf_16_dEta_1_Xhh_2 alpha_JET_EffectiveNP_Modelling4 -0.005329172323236179 0.9873946603026198
# ggf_16_dEta_1_Xhh_2 alpha_JET_EffectiveNP_Statistical1 0.00016233150076076092 0.9748334245438499
# ggf_16_dEta_1_Xhh_2 alpha_JET_EffectiveNP_Statistical2 0.001015707489221614 0.9787335903579253
# ggf_16_dEta_1_Xhh_2 alpha_JET_EffectiveNP_Statistical3 -0.0002868243171746951 0.9716371413911022
# ggf_16_dEta_1_Xhh_2 alpha_JET_EffectiveNP_Statistical4 -0.007830749980144443 0.9755774085713431
# ggf_16_dEta_1_Xhh_2 alpha_JET_EffectiveNP_Statistical5 0.005128399471892237 1.0047883346469781
# ggf_16_dEta_1_Xhh_2 alpha_JET_EffectiveNP_Statistical6 -0.007344630760645633 0.9940612460363729
# ggf_16_dEta_1_Xhh_2 alpha_JET_EtaIntercalibration_Modelling -0.015458487987202256 0.8047512121588433
# ggf_16_dEta_1_Xhh_2 alpha_JET_EtaIntercalibration_NonClosure_2018data -0.004883953591743286 1.0380558241633984
# ggf_16_dEta_1_Xhh_2 alpha_JET_EtaIntercalibration_NonClosure_highE -1.719483409822831e-05 0.9932824487927487
# ggf_16_dEta_1_Xhh_2 alpha_JET_EtaIntercalibration_NonClosure_negEta 5.120443027299476e-05 1.0061878033463163
# ggf_16_dEta_1_Xhh_2 alpha_JET_EtaIntercalibration_NonClosure_posEta 0.001746870036075863 0.9861331116992589
# ggf_16_dEta_1_Xhh_2 alpha_JET_EtaIntercalibration_TotalStat -0.00947523540750922 0.9634657860081906
# ggf_16_dEta_1_Xhh_2 alpha_JET_Flavor_Composition -0.014789638706064822 0.9584122008370903
# ggf_16_dEta_1_Xhh_2 alpha_JET_Flavor_Response 0.004593728146261699 0.956352175158389
# ggf_16_dEta_3_Xhh_1 alpha_CR12_shape_W_ggf_17 -0.09077454768037152 0.5077296400511733
# ggf_16_dEta_3_Xhh_1 alpha_CR12_shape_W_ggf_18 -0.9698305485694023 0.7464106283545502
# ggf_16_dEta_3_Xhh_1 alpha_FT_EFF_Eigen_B_0 -0.041427059914034885 0.9952045455677045
# ggf_16_dEta_3_Xhh_1 alpha_FT_EFF_Eigen_B_1 0.0009777333916646163 0.9900873403742273
# ggf_16_dEta_3_Xhh_1 alpha_FT_EFF_Eigen_B_2 0.022460706049268128 0.993556655640294
# ggf_16_dEta_3_Xhh_1 alpha_FT_EFF_Eigen_C_0 -0.0002046586927998812 0.9933466842607453
# ggf_16_dEta_3_Xhh_1 alpha_FT_EFF_Eigen_C_1 -5.50421824863259e-05 0.9933526219051745
# ggf_16_dEta_3_Xhh_1 alpha_FT_EFF_Eigen_C_2 3.557299177397435e-05 0.9933525247386102
# ggf_16_dEta_3_Xhh_1 alpha_FT_EFF_Eigen_C_3 -7.841183711687107e-06 0.9933524528929045
# ggf_16_dEta_3_Xhh_1 alpha_FT_EFF_Eigen_Light_0 8.345396658282402e-05 0.9933472359120243
# ggf_16_dEta_3_Xhh_1 alpha_FT_EFF_Eigen_Light_1 7.354596273454394e-05 0.9933524684752388
# ggf_16_dEta_3_Xhh_1 alpha_FT_EFF_Eigen_Light_2 -5.1503590978939015e-05 0.9933524330546835
# ggf_16_dEta_3_Xhh_1 alpha_FT_EFF_Eigen_Light_3 6.8543316226639395e-06 0.993352450526747
# ggf_16_dEta_3_Xhh_1 alpha_FT_EFF_extrapolation 0.0002995225584614893 0.9933188850151786
# ggf_16_dEta_3_Xhh_1 alpha_FT_EFF_extrapolation_from_charm -2.3700177398363557e-05 0.9933524791126707
# ggf_16_dEta_3_Xhh_1 alpha_HEFT_RW_SYST_lo_hi_mhh 0.015438172211627514 0.988938140234189
# ggf_16_dEta_3_Xhh_1 alpha_JET_BJES_Response -0.010344849621233138 0.7456243376355012
# ggf_16_dEta_3_Xhh_1 alpha_JET_EffectiveNP_Detector1 -0.006118074186670269 0.9712940436434903
# ggf_16_dEta_3_Xhh_1 alpha_JET_EffectiveNP_Detector2 -0.0017050121282824607 0.9933902063028721
# ggf_16_dEta_3_Xhh_1 alpha_JET_EffectiveNP_Mixed1 -0.0039006067541191244 0.9102881810271476
# ggf_16_dEta_3_Xhh_1 alpha_JET_EffectiveNP_Mixed2 0.0012356886607076691 0.8562188150465315
# ggf_16_dEta_3_Xhh_1 alpha_JET_EffectiveNP_Mixed3 -0.005192323406649639 0.9996447766384449
# ggf_16_dEta_3_Xhh_1 alpha_JET_EffectiveNP_Modelling1 -0.03203703603659376 0.7579716677292108
# ggf_16_dEta_3_Xhh_1 alpha_JET_EffectiveNP_Modelling2 -0.004686992653220829 0.9750758658485987
# ggf_16_dEta_3_Xhh_1 alpha_JET_EffectiveNP_Modelling3 0.009263209442878007 0.9462984743422221
# ggf_16_dEta_3_Xhh_1 alpha_JET_EffectiveNP_Modelling4 -0.005329172323236179 0.9873946603026198
# ggf_16_dEta_3_Xhh_1 alpha_JET_EffectiveNP_Statistical1 0.00016233150076076092 0.9748334245438499
# ggf_16_dEta_3_Xhh_1 alpha_JET_EffectiveNP_Statistical2 0.001015707489221614 0.9787335903579253
# ggf_16_dEta_3_Xhh_1 alpha_JET_EffectiveNP_Statistical3 -0.0002868243171746951 0.9716371413911022
# ggf_16_dEta_3_Xhh_1 alpha_JET_EffectiveNP_Statistical4 -0.007830749980144443 0.9755774085713431
# ggf_16_dEta_3_Xhh_1 alpha_JET_EffectiveNP_Statistical5 0.005128399471892237 1.0047883346469781
# ggf_16_dEta_3_Xhh_1 alpha_JET_EffectiveNP_Statistical6 -0.007344630760645633 0.9940612460363729
# ggf_16_dEta_3_Xhh_1 alpha_JET_EtaIntercalibration_Modelling -0.015458487987202256 0.8047512121588433
# ggf_16_dEta_3_Xhh_1 alpha_JET_EtaIntercalibration_NonClosure_2018data -0.004883953591743286 1.0380558241633984
# ggf_16_dEta_3_Xhh_1 alpha_JET_EtaIntercalibration_NonClosure_highE -1.719483409822831e-05 0.9932824487927487
# ggf_16_dEta_3_Xhh_1 alpha_JET_EtaIntercalibration_NonClosure_negEta 5.120443027299476e-05 1.0061878033463163
# ggf_16_dEta_3_Xhh_1 alpha_JET_EtaIntercalibration_NonClosure_posEta 0.001746870036075863 0.9861331116992589
# ggf_16_dEta_3_Xhh_1 alpha_JET_EtaIntercalibration_TotalStat -0.00947523540750922 0.9634657860081906
# ggf_16_dEta_3_Xhh_1 alpha_JET_Flavor_Composition -0.014789638706064822 0.9584122008370903
# ggf_16_dEta_3_Xhh_1 alpha_JET_Flavor_Response 0.004593728146261699 0.956352175158389
# ggf_16_dEta_3_Xhh_1 alpha_JET_JER_DataVsMC_MC16 0.010491992731881842 0.8445510252569917
# ggf_16_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_1 0.030419452409371234 0.7045794727286467
# ggf_16_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_10 -0.02098192224263878 0.9793936260667258
# ggf_16_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_11 -0.015863810471495123 0.8796117766774343
# ggf_16_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_12restTerm -0.03970503477113964 0.8614482934662158
# ggf_16_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_2 0.046670720773407566 0.9713152825608283
# ggf_16_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_3 0.01624105138125343 1.2179678953822974
# ggf_16_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_4 0.030053065999980946 0.9899338384340421
# ggf_16_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_5 -0.049850507454804155 1.0099865161208732
# ggf_16_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_6 -0.001699012392611745 0.929601904722595
# ggf_16_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_7 -0.052159294601997086 1.0062611013567446
# ggf_16_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_8 -0.004357362359565235 0.963216184745399
# ggf_16_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_9 -0.056007978930007626 0.8893604029353841
# ggf_16_dEta_3_Xhh_1 alpha_JET_JVT 0.004332085513117571 0.9927367227372768
# ggf_16_dEta_3_Xhh_1 alpha_JET_Pileup_OffsetMu -0.0008460770069420673 0.8609795938504884
# ggf_16_dEta_3_Xhh_1 alpha_JET_Pileup_OffsetNPV -0.03058630112389176 0.69979881830878
# ggf_16_dEta_3_Xhh_1 alpha_JET_Pileup_PtTerm -0.015979042418962145 0.8363094414402341
# ggf_16_dEta_3_Xhh_1 alpha_JET_Pileup_RhoTopology -0.01705155651286933 0.7091578138606103
# ggf_16_dEta_3_Xhh_1 alpha_JET_PunchThrough_MC16 -0.002404262962248308 0.9824641235405988
# ggf_16_dEta_3_Xhh_1 alpha_JET_SingleParticle_HighPt 0.0 0.9931555059785103
# ggf_16_dEta_3_Xhh_1 alpha_NC_3b1f_ggf_16 0.2690091337578912 0.8332663826237519
# ggf_16_dEta_3_Xhh_1 alpha_NC_3b1f_ggf_17 -0.6907756903548906 0.7233131907718247
# ggf_16_dEta_3_Xhh_1 alpha_NC_3b1f_ggf_18 0.6950075070589452 0.6464737460636338
# ggf_16_dEta_3_Xhh_1 alpha_SF_PRW 0.025745467288081556 0.9994551224603602
# ggf_16_dEta_3_Xhh_1 alpha_THEO_ACC_PDFalphas_ggf 0.00669268450895681 0.9932173493998573
# ggf_16_dEta_3_Xhh_1 alpha_THEO_ACC_PS_ggf -0.08029523038420842 0.7360722308660079
# ...
# ggf_18_dEta_3_Xhh_1 alpha_JET_JER_DataVsMC_MC16 0.010491992731881842 0.8445510252569917
# ggf_18_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_1 0.030419452409371234 0.7045794727286467
# ggf_18_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_10 -0.02098192224263878 0.9793936260667258
# ggf_18_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_11 -0.015863810471495123 0.8796117766774343
# ggf_18_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_12restTerm -0.03970503477113964 0.8614482934662158
# ggf_18_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_2 0.046670720773407566 0.9713152825608283
# ggf_18_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_3 0.01624105138125343 1.2179678953822974
# ggf_18_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_4 0.030053065999980946 0.9899338384340421
# ggf_18_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_5 -0.049850507454804155 1.0099865161208732
# ggf_18_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_6 -0.001699012392611745 0.929601904722595
# ggf_18_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_7 -0.052159294601997086 1.0062611013567446
# ggf_18_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_8 -0.004357362359565235 0.963216184745399
# ggf_18_dEta_3_Xhh_1 alpha_JET_JER_EffectiveNP_9 -0.056007978930007626 0.8893604029353841
# ggf_18_dEta_3_Xhh_2 alpha_FT_EFF_extrapolation_from_charm -2.3700177398363557e-05 0.9933524791126707
# ggf_18_dEta_3_Xhh_2 alpha_HEFT_RW_SYST_lo_hi_mhh 0.015438172211627514 0.988938140234189
# ggf_18_dEta_3_Xhh_2 alpha_JET_BJES_Response -0.010344849621233138 0.7456243376355012
# ggf_18_dEta_3_Xhh_2 alpha_JET_EffectiveNP_Detector1 -0.006118074186670269 0.9712940436434903
# ggf_18_dEta_3_Xhh_2 alpha_JET_EffectiveNP_Detector2 -0.0017050121282824607 0.9933902063028721
# ggf_18_dEta_3_Xhh_2 alpha_JET_EffectiveNP_Mixed1 -0.0039006067541191244 0.9102881810271476
# ggf_18_dEta_3_Xhh_2 alpha_JET_EffectiveNP_Mixed2 0.0012356886607076691 0.8562188150465315
# ggf_18_dEta_3_Xhh_2 alpha_JET_EffectiveNP_Mixed3 -0.005192323406649639 0.9996447766384449
# ggf_18_dEta_3_Xhh_2 alpha_JET_EffectiveNP_Modelling1 -0.03203703603659376 0.7579716677292108
# ggf_18_dEta_3_Xhh_2 alpha_JET_EffectiveNP_Modelling2 -0.004686992653220829 0.9750758658485987
# ggf_18_dEta_3_Xhh_2 alpha_JET_EffectiveNP_Modelling3 0.009263209442878007 0.9462984743422221
# ggf_18_dEta_3_Xhh_2 alpha_JET_EffectiveNP_Modelling4 -0.005329172323236179 0.9873946603026198
# ggf_18_dEta_3_Xhh_2 alpha_JET_EffectiveNP_Statistical1 0.00016233150076076092 0.9748334245438499
# ggf_18_dEta_3_Xhh_2 alpha_JET_EffectiveNP_Statistical2 0.001015707489221614 0.9787335903579253
# ggf_18_dEta_3_Xhh_2 alpha_JET_EffectiveNP_Statistical3 -0.0002868243171746951 0.9716371413911022
# ggf_18_dEta_3_Xhh_2 alpha_JET_EffectiveNP_Statistical4 -0.007830749980144443 0.9755774085713431
# ggf_18_dEta_3_Xhh_2 alpha_JET_EffectiveNP_Statistical5 0.005128399471892237 1.0047883346469781
# ggf_18_dEta_3_Xhh_2 alpha_JET_EffectiveNP_Statistical6 -0.007344630760645633 0.9940612460363729
# ggf_18_dEta_3_Xhh_2 alpha_JET_EtaIntercalibration_Modelling -0.015458487987202256 0.8047512121588433
# ggf_18_dEta_3_Xhh_2 alpha_JET_EtaIntercalibration_NonClosure_2018data -0.004883953591743286 1.0380558241633984
# ggf_18_dEta_3_Xhh_2 alpha_JET_EtaIntercalibration_NonClosure_highE -1.719483409822831e-05 0.9932824487927487
# ggf_18_dEta_3_Xhh_2 alpha_JET_EtaIntercalibration_NonClosure_negEta 5.120443027299476e-05 1.0061878033463163
# ggf_18_dEta_3_Xhh_2 alpha_JET_EtaIntercalibration_NonClosure_posEta 0.001746870036075863 0.9861331116992589
# ggf_18_dEta_3_Xhh_2 alpha_JET_EtaIntercalibration_TotalStat -0.00947523540750922 0.9634657860081906
# ggf_18_dEta_3_Xhh_2 alpha_JET_Flavor_Composition -0.014789638706064822 0.9584122008370903
# ggf_18_dEta_3_Xhh_2 gamma_stat_ggf_18_dEta_3_Xhh_2_bin_10 0.9814961204468933 0.08105887581953969
# ggf_18_dEta_3_Xhh_2 gamma_stat_ggf_18_dEta_3_Xhh_2_bin_11 1.0949785868345683 0.08391320620245524
# ggf_18_dEta_3_Xhh_2 gamma_stat_ggf_18_dEta_3_Xhh_2_bin_12 1.0752001605429269 0.10147232364473457
# ggf_18_dEta_3_Xhh_2 gamma_stat_ggf_18_dEta_3_Xhh_2_bin_13 0.9608071915877158 0.12611743320566748
# ggf_18_dEta_3_Xhh_2 gamma_stat_ggf_18_dEta_3_Xhh_2_bin_14 0.9988977936081984 0.13473883173920237
# ggf_18_dEta_3_Xhh_2 gamma_stat_ggf_18_dEta_3_Xhh_2_bin_2 1.0172242349252756 0.04614662625949256
# ggf_18_dEta_3_Xhh_2 gamma_stat_ggf_18_dEta_3_Xhh_2_bin_3 1.03363599606981 0.038051290369212676
# ggf_18_dEta_3_Xhh_2 gamma_stat_ggf_18_dEta_3_Xhh_2_bin_4 1.0016826001954937 0.03637859399221721
# ggf_18_dEta_3_Xhh_2 gamma_stat_ggf_18_dEta_3_Xhh_2_bin_5 0.9903262946015571 0.038641982697076305
# ggf_18_dEta_3_Xhh_2 gamma_stat_ggf_18_dEta_3_Xhh_2_bin_6 1.029473013971009 0.04132910376563104
# ggf_18_dEta_3_Xhh_2 gamma_stat_ggf_18_dEta_3_Xhh_2_bin_7 0.9158220557403572 0.0599075409539358
# ggf_18_dEta_3_Xhh_2 gamma_stat_ggf_18_dEta_3_Xhh_2_bin_8 0.9682692231365283 0.05959732291960401
# ggf_18_dEta_3_Xhh_2 gamma_stat_ggf_18_dEta_3_Xhh_2_bin_9 1.0164032625244743 0.06572174971763023
# Save to bbbb_postfit.root

# %%
collected_distributions = model.get_collected_distributions(True,[data.GetName()],snapshots=['chhh_fit'])
fo = ROOT.TFile("bbbb_data.root","RECREATE")
for cat in collected_distributions:
    if len(cat_map[cat]["observables"].keys())==1:
        observable = model.workspace.obj(list(cat_map[cat]["observables"].keys())[0])
    else:
        print("More than one observable in category, not supported yet")
        continue
    for case in collected_distributions[cat]:
        hist = ROOT.TH1F(cat+"_"+case, cat+"_"+case, observable.getBins(), observable.getMin(), observable.getMax())
        for i,x in enumerate(collected_distributions[cat][case]['x']):
            hist.SetBinContent(i+1, collected_distributions[cat][case]['y'][i])
            hist.SetBinError(i+1, np.sqrt(collected_distributions[cat][case]['y'][i]))
        fo.cd()
        hist.Write()
fo.Close()
# Out:
# [#1] INFO:Fitting -- using CPU computation library compiled with -mavx2

# %% [markdown]
# # Pre-fit

# %%
aplt.set_atlas_style()
f_d = ROOT.TFile("bbbb_data.root","READ")
f_a = ROOT.TFile("bbbb_prefit.root","READ")
for cat in collected_distributions:
    h_d = f_d.Get(f"{cat}_combData")
    h_aus = {}
    for h in f_a.GetListOfKeys():
        hname = h.GetName()
        if cat not in hname: continue
        if 'up' in hname:
            h_aus[hname] = f_a.Get(hname)
        elif 'down' in hname:
            continue
        else:
            h_a = f_a.Get(hname)
    x,y,ye_error,xe_error,ye_error_ratio,y_ratio = [],[],[],[],[],[]
    chi2 = 0
    for i in range(h_a.GetNbinsX()):
        error2 = 0
        for j in h_aus:
            error2 += (h_aus[j].GetBinContent(i+1)-h_a.GetBinContent(i+1))**2
        x.append(h_a.GetBinCenter(i+1))
        y.append(h_a.GetBinContent(i+1))
        ye_error.append(np.sqrt(error2))
        xe_error.append(h_a.GetBinWidth(i+1)/2)
        ye_error_ratio.append(ye_error[-1]/y[-1])
        y_ratio.append(1.)
        chi2 +=  (y[-1] - h_d.GetBinContent(i+1))**2/(error2+h_d.GetBinContent(i+1))
    hg = ROOT.TGraphAsymmErrors(len(x),np.array(x),np.array(y),np.array(xe_error),np.array(xe_error),np.array(ye_error),np.array(ye_error))
    hg_ratio = ROOT.TGraphAsymmErrors(len(x),np.array(x),np.array(y_ratio),np.array(xe_error),np.array(xe_error),np.array(ye_error_ratio),np.array(ye_error_ratio))
    fig, (ax1, ax2) = aplt.ratio_plot(name=cat, figsize=(800, 800), hspace=0.05)
    ax1.plot(h_d, "EP X0", label="Data", labelfmt="EP")
    ax1.plot(h_a, linecolor=ROOT.kRed+1, label="Pre-fit S+B", labelfmt="L")
    ax1.plot(hg, "2", fillcolor=1, fillstyle=3254, linewidth=0)
    h_d_ratio = h_d.Clone()
    h_d_ratio.Divide(h_a)
    line = ROOT.TLine(ax1.get_xlim()[0], 1, ax1.get_xlim()[1], 1)
    ax2.plot(line)
    ax2.plot(h_d_ratio, "EP X0")
    ax2.plot(hg_ratio, "2", fillcolor=1, fillstyle=3254, linewidth=0)
    ax2.set_ylim(0.5, 2.0)
    ax2.set_ylabel("Ratio to MC")
    ax2.text(0.6, 0.1, cat, size=28)
    ax1.set_ylabel("Events")
    ax1.add_margins(top=0.15)
    ax1.legend(loc=(0.65, 0.75, 0.92, 0.90))
    ax1.text(0.6, 0.65, f"Chi2 = {chi2:.2f}, ndf = {h_a.GetNbinsX()}", size=26)
    fig.savefig(f"prefit_bbbb/{cat}.png")
# Out:
# Applying ATLAS style settings
# Info in <TCanvas::Print>: png file prefit_bbbb/ggf_16_dEta_1_Xhh_1.png has been created
# Info in <TCanvas::Print>: png file prefit_bbbb/ggf_16_dEta_1_Xhh_2.png has been created
# Info in <TCanvas::Print>: png file prefit_bbbb/ggf_16_dEta_2_Xhh_1.png has been created
# Info in <TCanvas::Print>: png file prefit_bbbb/ggf_16_dEta_2_Xhh_2.png has been created
# Info in <TCanvas::Print>: png file prefit_bbbb/ggf_16_dEta_3_Xhh_1.png has been created
# Info in <TCanvas::Print>: png file prefit_bbbb/ggf_16_dEta_3_Xhh_2.png has been created
# Info in <TCanvas::Print>: png file prefit_bbbb/ggf_17_dEta_1_Xhh_1.png has been created
# Info in <TCanvas::Print>: png file prefit_bbbb/ggf_17_dEta_1_Xhh_2.png has been created
# Info in <TCanvas::Print>: png file prefit_bbbb/ggf_17_dEta_2_Xhh_1.png has been created
# Info in <TCanvas::Print>: png file prefit_bbbb/ggf_17_dEta_2_Xhh_2.png has been created
# Info in <TCanvas::Print>: png file prefit_bbbb/ggf_17_dEta_3_Xhh_1.png has been created
# Info in <TCanvas::Print>: png file prefit_bbbb/ggf_17_dEta_3_Xhh_2.png has been created
# Info in <TCanvas::Print>: png file prefit_bbbb/ggf_18_dEta_1_Xhh_1.png has been created
# Info in <TCanvas::Print>: png file prefit_bbbb/ggf_18_dEta_1_Xhh_2.png has been created
# Info in <TCanvas::Print>: png file prefit_bbbb/ggf_18_dEta_2_Xhh_1.png has been created
# Info in <TCanvas::Print>: png file prefit_bbbb/ggf_18_dEta_2_Xhh_2.png has been created
# Info in <TCanvas::Print>: png file prefit_bbbb/ggf_18_dEta_3_Xhh_1.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ggf_18_dEta_3_Xhh_2
# Info in <TCanvas::Print>: png file prefit_bbbb/ggf_18_dEta_3_Xhh_2.png has been created

# %% [markdown]
# # Post-fit

# %%
aplt.set_atlas_style()
f_d = ROOT.TFile("bbbb_data.root","READ")
f_a = ROOT.TFile("bbbb_postfit.root","READ")
f_c = ROOT.TFile("/afs/ihep.ac.cn/users/c/cyz/besfs/HH_comb/hh_combination_fw_new/run_heft_final/output/workspace/heft/bbbb/chhh_fit.root","READ")
correlation = f_c.Get("correlation_matrix")
for cat in collected_distributions:
    h_d = f_d.Get(f"{cat}_combData")
    h_aus = {}
    for h in f_a.GetListOfKeys():
        hname = h.GetName()
        if cat not in hname: continue
        if 'up' in hname:
            h_aus[hname] = f_a.Get(hname)
        elif 'down' in hname:
            continue
        else:
            h_a = f_a.Get(hname)
    x,y,ye_error,xe_error,ye_error_ratio,y_ratio = [],[],[],[],[],[]
    nbin = h_a.GetNbinsX()
    for i in range(nbin):
        error2 = 0
        for n in h_aus:
            error2 += (h_aus[n].GetBinContent(i+1)-h_a.GetBinContent(i+1))**2
        x.append(h_a.GetBinCenter(i+1))
        y.append(h_a.GetBinContent(i+1))
        ye_error.append(np.sqrt(error2))
        xe_error.append(h_a.GetBinWidth(i+1)/2)
        ye_error_ratio.append(ye_error[-1]/y[-1])
        y_ratio.append(1.)
    c = np.zeros((nbin, nbin))
    for i in range(nbin):
        ynom_i = y[i]
        for j in range(i, nbin):
            sumbin = 0
            ynom_j = y[j]
            for n in h_aus:
                ysyst_i_n = h_aus[n].GetBinContent(i+1)
                for m in h_aus:
                    ysyst_j_m = h_aus[m].GetBinContent(j+1)
                    if n == m:
                        corr = 1.
                    else:
                        n_bin = correlation.GetXaxis().FindBin(n)
                        m_bin = correlation.GetYaxis().FindBin(m)
                        corr = correlation.GetBinContent(n_bin, m_bin)
                    sumbin += (ysyst_i_n - ynom_i) * corr * (ysyst_j_m - ynom_j)
            if i == j:
                sumbin += ynom_i
            c[i, j] = sumbin
            if i != j:
                c[j, i] = sumbin
    c = np.linalg.inv(c)
    chi2 = 0
    for i in range(nbin):
        for j in range(nbin):
            chi2 += (y[i] - h_d.GetBinContent(i+1)) * c[i, j] * (y[j] - h_d.GetBinContent(j+1))
    hg = ROOT.TGraphAsymmErrors(len(x),np.array(x),np.array(y),np.array(xe_error),np.array(xe_error),np.array(ye_error),np.array(ye_error))
    hg_ratio = ROOT.TGraphAsymmErrors(len(x),np.array(x),np.array(y_ratio),np.array(xe_error),np.array(xe_error),np.array(ye_error_ratio),np.array(ye_error_ratio))
    fig, (ax1, ax2) = aplt.ratio_plot(name=cat, figsize=(800, 800), hspace=0.05)
    ax1.plot(h_d, "EP X0", label="Data", labelfmt="EP")
    ax1.plot(h_a, linecolor=ROOT.kRed+1, label="Post-fit S+B", labelfmt="L")
    ax1.plot(hg, "2", fillcolor=1, fillstyle=3254, linewidth=0)
    h_d_ratio = h_d.Clone()
    h_d_ratio.Divide(h_a)
    ax2.plot(h_d_ratio, "EP X0")
    ax2.plot(hg_ratio, "2", fillcolor=1, fillstyle=3254, linewidth=0)
    ax2.set_ylim(0.5, 2.0)
    ax2.set_ylabel("Ratio to MC")
    ax2.text(0.6, 0.1, cat, size=28)
    ax1.set_ylabel("Events")
    ax1.add_margins(top=0.15)
    ax1.legend(loc=(0.65, 0.75, 0.92, 0.90))
    ax1.text(0.6, 0.65, f"Chi2 = {chi2:.2f}, ndf = {nbin}", size=26)
    fig.savefig(f"postfit_bbbb/{cat}.png")
# Out:
# Applying ATLAS style settings
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ggf_16_dEta_1_Xhh_1
# Info in <TCanvas::Print>: png file postfit_bbbb/ggf_16_dEta_1_Xhh_1.png has been created
# Info in <TCanvas::Print>: png file postfit_bbbb/ggf_16_dEta_1_Xhh_2.png has been created
# Info in <TCanvas::Print>: png file postfit_bbbb/ggf_16_dEta_2_Xhh_1.png has been created
# Info in <TCanvas::Print>: png file postfit_bbbb/ggf_16_dEta_2_Xhh_2.png has been created
# Info in <TCanvas::Print>: png file postfit_bbbb/ggf_16_dEta_3_Xhh_1.png has been created
# Info in <TCanvas::Print>: png file postfit_bbbb/ggf_16_dEta_3_Xhh_2.png has been created
# Info in <TCanvas::Print>: png file postfit_bbbb/ggf_17_dEta_1_Xhh_1.png has been created
# Info in <TCanvas::Print>: png file postfit_bbbb/ggf_17_dEta_1_Xhh_2.png has been created
# Info in <TCanvas::Print>: png file postfit_bbbb/ggf_17_dEta_2_Xhh_1.png has been created
# Info in <TCanvas::Print>: png file postfit_bbbb/ggf_17_dEta_2_Xhh_2.png has been created
# Info in <TCanvas::Print>: png file postfit_bbbb/ggf_17_dEta_3_Xhh_1.png has been created
# Info in <TCanvas::Print>: png file postfit_bbbb/ggf_17_dEta_3_Xhh_2.png has been created
# Info in <TCanvas::Print>: png file postfit_bbbb/ggf_18_dEta_1_Xhh_1.png has been created
# Info in <TCanvas::Print>: png file postfit_bbbb/ggf_18_dEta_1_Xhh_2.png has been created
# Info in <TCanvas::Print>: png file postfit_bbbb/ggf_18_dEta_2_Xhh_1.png has been created
# Info in <TCanvas::Print>: png file postfit_bbbb/ggf_18_dEta_2_Xhh_2.png has been created
# Info in <TCanvas::Print>: png file postfit_bbbb/ggf_18_dEta_3_Xhh_1.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: ggf_18_dEta_3_Xhh_2
# Info in <TCanvas::Print>: png file postfit_bbbb/ggf_18_dEta_3_Xhh_2.png has been created
