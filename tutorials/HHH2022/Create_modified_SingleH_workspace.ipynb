# %%
import os
import glob
import json
import quickstats
import sys, numpy as np
from quickstats.components.workspaces import XMLWSModifier
# Out:
# Welcome to JupyROOT 6.24/06
#
# RooFit v3.60 -- Developed by Wouter Verkerke and David Kirkby
#                 Copyright (C) 2000-2013 NIKHEF, University of California & Stanford University
#                 All rights reserved, please read http://roofit.sourceforge.net/license.txt

# %%
# make sure hh combination fw path is defined
hh_comb_fw_path = os.environ.get('hh_combination_fw_path', None)
assert hh_comb_fw_path

# %%
workspace_dir = os.path.join(hh_comb_fw_path, "FullRun2Workspaces/original/HHH2022/")
H_workspace_path = os.path.join(workspace_dir, "20220425/singleH/nonres", "obs.root")

modification_xml_path = os.path.join(hh_comb_fw_path, "configs/modification/HHH2022/modify_singleH_STXS_newC1kEW.xml")

# change your output directory here
output_dir = os.path.join(os.getcwd(), "outputs_H_HH_combination_06_06_2022")
modified_H_workspace_path = os.path.join(output_dir, "workspaces", "H.root")

# %%
modifier = XMLWSModifier(modification_xml_path)
# Out:
# INFO: Set stack size to unlimited
# INFO: Loaded extension module "FlexibleInterpVarMkII"

# %%
modifier.create_modified_workspace(infile=H_workspace_path, outfile=modified_H_workspace_path)
# Out:
# INFO: Begin modification of the workspace "/afs/cern.ch/work/c/chlcheng/Repository/hh_combination_fw/FullRun2Workspaces/original/HHH2022/20220425/singleH/nonres/obs.root".
#
# 	 ----------------------------------------------
# 	 ---------- Step 1: Redefine objects ----------
# 	 ----------------------------------------------
#
# INFO: No objects are redefined.
#
# 	 ------------------------------------------------
# 	 ---------- Step 2: Create new objects ----------
# 	 ------------------------------------------------
#
# INFO: (Item 0) k3[1]
# INFO: (Item 1) kV[1]
# INFO: (Item 2) sum::kW(kV)
# INFO: (Item 3) sum::kZ(kV)
# INFO: (Item 4) kt[1]
# INFO: (Item 5) kb[1]
# INFO: (Item 6) ktau[1]
# INFO: (Item 7) unit[1]
# INFO: (Item 8) sum::kc(kt)
# INFO: (Item 9) sum::ks(kb)
# INFO: (Item 10) sum::kmu(ktau)
# INFO: (Item 11) expr::kb2('@0*@0',kb)
# ...
